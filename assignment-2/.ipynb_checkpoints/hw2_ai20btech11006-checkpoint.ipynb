# %%
#importing librarier
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
#defining sigmoid function and its derivative
def sigmoid (x):
    return 1/(1+np.exp(-x))

def sigmoid_der (x):
    return sigmoid(x)*(1-sigmoid(x))

#mean , standard deviation for noise
mean=0
std=0.03

# %%
# The follwoing is for XOR
# number of test cases

#initialisation of weight vectors
alpha=np.random.uniform(-4,4,6)
alpha=alpha.reshape(3,2)
beta=np.array([np.random.uniform(-4,4,3)]).T


# The follwoing is for AND
# number of test cases
T=1000
N=int(0.8*T)
M=int(0.2*T)

y=np.ones(T)

# each node in input layer is either 0 or 1 (with some noise)
x1=np.random.randint(0,2,T)
x2=np.random.randint(0,2,T)

#converting to float
x1=x1.astype(float)
x2=x2.astype(float)

#if both nodes are 1 then output node should be 1
for i in range(T):
    if x1[i]==0 and x2[i]==0:
        y[i]=0
    elif x1[i] and x2[i]:
        y[i]=0
        
#adding noise
x1 += np.random.normal(mean, std, T)
x2 += np.random.normal(mean, std, T)

# appending a row of ones, reshaping the matrix
X=np.array([np.ones(T),x1,x2])
X=X.reshape(3,T)


#plotting the input data points
plt.plot(X[1,:],X[2,:],'o',label='pts')
plt.legend()
plt.grid(1)
plt.xlabel('x1')
plt.ylabel('x2') 
plt.show()

#size of mini batch
m=50
#number of epochs
epoch =100
#learning rate
gamma=0.05

#The vector for mse values of training data
R_train=np.empty([1])
#The vector for mse values of testing data
R_test=np.empty([1])

# looping over epoch
for i in range(epoch):
    #looping over the mini batches
    for j in range(N//m):
        #z is sgm(alpha.T * X)
        z=np.matmul(alpha.T,X[:,j*m:(j+1)*m])
        z=z.reshape(1,2*m)
        for idx in range(2*m):
            z[0][idx]=sigmoid(z[0][idx]) 
        
        z=np.append(np.ones(m),z)
        z=z.reshape(3,m)     
        #y_cap is sigmoid of beta.T * z
        y_cap=np.matmul(beta.T,z)
        
        for idx in range(m):
            y_cap[0][idx]=sigmoid(y_cap[0][idx])
        #print(beta,y_cap)
        delta=-2*(y[j*m:(j+1)*m]-y_cap)
        
        #making the delta vector( 1 cross m)
        for idx in range(m):
                delta[0][idx]=delta[0][idx]*sigmoid_der(np.dot(beta.T,z[:,idx]))
        # making the S matrix (3 cross m)
        S=np.matmul(beta,delta)
        for idx in range(3):
            for itr in range(m):
                S[idx][itr]=S[idx][itr]*sigmoid(z[idx][itr])*(1-sigmoid(z[idx][itr]))
        
        #updating the weight vector
        beta-=gamma*np.matmul(z,delta.T)
        alpha-=gamma*np.matmul(S,X[1:,j*m:(j+1)*m].T)
        
    # finding z after every epoch        
    z=np.matmul(alpha.T,X)
    z=z.reshape(1,2*T)
    for idx in range(2*T):
        z[0][idx]=sigmoid(z[0][idx])
    
    z=np.append(np.ones(T),z)
    z=z.reshape(3,T)
    
    #finding the y cap after every epoch 
    y_cap=np.matmul(beta.T,z)   
    for idx in range(T):
        y_cap[0][idx]=sigmoid(y_cap[0][idx])
    
    # storing the errors in an array
    print("epoch:",i+1)
    R_train=np.append(R_train,np.sum((y[:N]-y_cap[0,:N])**2)/N)
    R_test=np.append(R_test,np.sum((y[N:T]-y_cap[0,N:T])**2)/M)
    print("Training error",np.sum((y[:N]-y_cap[0,:N])**2)/N)
    print("Testing error",np.sum((y[N:T]-y_cap[0,N:T])**2)/M)
#print("Observation: Saddle point is reached")    
#plotting the results
plt.plot(np.linspace(1,epoch,epoch),R_train[1:], 'r',label='training error')
plt.plot(np.linspace(1,epoch,epoch),R_test[1:],label='testing error')
plt.legend()
plt.grid()
plt.show()
# Out:
# epoch: 1
# Training error 0.26059454094036894
# Testing error 0.26684750795701484
# epoch: 2
# Training error 0.25695222716014227
# Testing error 0.26168587616734196
# epoch: 3
# Training error 0.25503800343039856
# Testing error 0.2589515425907234
# epoch: 4
# Training error 0.2539357495118179
# Testing error 0.25738634545411365
# epoch: 5
# Training error 0.25325708661473395
# Testing error 0.25644357848109406
# epoch: 6
# Training error 0.25281560621879273
# Testing error 0.2558577432885582
# epoch: 7
# Training error 0.25251244979190723
# Testing error 0.2554871724305206
# epoch: 8
# Training error 0.2522915447972353
# Testing error 0.2552507840374205
# epoch: 9
# Training error 0.2521197178708533
# Testing error 0.25509969924018705
# epoch: 10
# Training error 0.2519769062734196
# Testing error 0.2550032724017824
# epoch: 11
# Training error 0.25185100746630246
# Testing error 0.2549417377560827
# epoch: 12
# Training error 0.25173507699978886
# Testing error 0.2549021670042092
# epoch: 13
# Training error 0.2516257919747285
# Testing error 0.25487619422084573
# epoch: 14
# Training error 0.2515226070898999
# Testing error 0.254858721175151
# epoch: 15
# Training error 0.2514272622788574
# Testing error 0.2548471640493365
# epoch: 16
# Training error 0.251343412106875
# Testing error 0.2548409695588735
# epoch: 17
# Training error 0.2512762070544849
# Testing error 0.25484121334303605
# epoch: 18
# Training error 0.2512317041286191
# Testing error 0.25485014648128596
# epoch: 19
# Training error 0.25121604360149513
# Testing error 0.2548706068944113
# epoch: 20
# Training error 0.2512344124428915
# Testing error 0.25490527780243577
# epoch: 21
# Training error 0.25128991837519715
# Testing error 0.25495585720136105
# epoch: 22
# Training error 0.2513825956481056
# Testing error 0.25502228471833865
# epoch: 23
# Training error 0.2515088128897799
# Testing error 0.2551022245261455
# epoch: 24
# Training error 0.2516613153843983
# Testing error 0.25519099249421684
# epoch: 25
# Training error 0.25182999781989157
# Testing error 0.2552820277642165
# epoch: 26
# Training error 0.25200330360646667
# Testing error 0.2553678626706109
# epoch: 27
# Training error 0.2521699556839121
# Testing error 0.2554413913624831
# epoch: 28
# Training error 0.2523206175358041
# Testing error 0.2554971366575793
# epoch: 29
# Training error 0.25244910292514366
# Testing error 0.2555322058890877
# epoch: 30
# Training error 0.2525528866538356
# Testing error 0.2555467112381838
# epoch: 31
# Training error 0.2526328636705993
# Testing error 0.2555435760741159
# epoch: 32
# Training error 0.2526924950628109
# Testing error 0.2555278081493962
# epoch: 33
# Training error 0.2527366140554379
# Testing error 0.2555054473412921
# epoch: 34
# Training error 0.2527702140882985
# Testing error 0.2554824578317256
# epoch: 35
# Training error 0.25279750100652865
# Testing error 0.25546381962913733
# epoch: 36
# Training error 0.25282138230369094
# Testing error 0.2554529918501796
# epoch: 37
# Training error 0.2528434255175562
# Testing error 0.2554517998492363
# epoch: 38
# Training error 0.2528641891245099
# Testing error 0.25546068027106117
# epoch: 39
# Training error 0.252883748652303
# Testing error 0.2554791383859959
# epoch: 40
# Training error 0.25290222456209077
# Training error 0.2543421274406016
# Testing error 0.25705374352607735
# epoch: 85
# Training error 0.25425949766752004
# Testing error 0.2569680039644215
# epoch: 86
# Training error 0.2541615936772015
# Testing error 0.2568670101324963
# epoch: 87
# Training error 0.2540467273693877
# Testing error 0.2567491876671931
# epoch: 88
# Training error 0.253912899837416
# Testing error 0.2566126537926423
# epoch: 89
# Training error 0.25375770550687315
# Testing error 0.256455120569106
# epoch: 90
# Training error 0.25357820454001234
# Testing error 0.25627376679286035
# epoch: 91
# Training error 0.25337075120236197
# Testing error 0.2560650660275474
# epoch: 92
# Training error 0.2531307601904628
# Testing error 0.2558245524267066
# epoch: 93
# Training error 0.25285238435956253
# Testing error 0.25554649724720135
# epoch: 94
# Training error 0.25252806425495583
# Testing error 0.25522345558041004
# epoch: 95
# Training error 0.252147889732955
# Testing error 0.2548456221243431
# epoch: 96
# Training error 0.2516986824989762
# Testing error 0.25439990232223875
# epoch: 97
# Training error 0.2511626585741285
# Testing error 0.25386855349539067
# epoch: 98
# Training error 0.25051544988807967
# Testing error 0.2532271672994668
# epoch: 99
# Training error 0.24972313503736449
# Testing error 0.25244162905916423
# epoch: 100
# Training error 0.2487377188072391
# Testing error 0.25146346618695525

# %%
# The follwoing is for XOR
# number of test cases

#initialisation of weight vectors
alpha=np.random.uniform(-4,4,6)
alpha=alpha.reshape(3,2)
beta=np.array([np.random.uniform(-4,4,3)]).T


# The follwoing is for AND
# number of test cases
T=2500
N=int(0.8*T)
M=int(0.2*T)

y=np.ones(T)

# each node in input layer is either 0 or 1 (with some noise)
x1=np.random.randint(0,2,T)
x2=np.random.randint(0,2,T)

#converting to float
x1=x1.astype(float)
x2=x2.astype(float)

#if both nodes are 1 then output node should be 1
for i in range(T):
    if x1[i]==0 and x2[i]==0:
        y[i]=0
    elif x1[i] and x2[i]:
        y[i]=0
        
#adding noise
x1 += np.random.normal(mean, std, T)
x2 += np.random.normal(mean, std, T)

# appending a row of ones, reshaping the matrix
X=np.array([np.ones(T),x1,x2])
X=X.reshape(3,T)


#plotting the input data points
plt.plot(X[1,:],X[2,:],'o',label='pts')
plt.legend()
plt.grid(1)
plt.xlabel('x1')
plt.ylabel('x2') 
plt.show()

#size of mini batch
m=50
#number of epochs
epoch =100
#learning rate
gamma=0.05

#The vector for mse values of training data
R_train=np.empty([1])
#The vector for mse values of testing data
R_test=np.empty([1])

# looping over epoch
for i in range(epoch):
    #looping over the mini batches
    for j in range(N//m):
        #z is sgm(alpha.T * X)
        z=np.matmul(alpha.T,X[:,j*m:(j+1)*m])
        z=z.reshape(1,2*m)
        for idx in range(2*m):
            z[0][idx]=sigmoid(z[0][idx]) 
        
        z=np.append(np.ones(m),z)
        z=z.reshape(3,m)     
        #y_cap is sigmoid of beta.T * z
        y_cap=np.matmul(beta.T,z)
        
        for idx in range(m):
            y_cap[0][idx]=sigmoid(y_cap[0][idx])
        #print(beta,y_cap)
        delta=-2*(y[j*m:(j+1)*m]-y_cap)
        
        #making the delta vector( 1 cross m)
        for idx in range(m):
                delta[0][idx]=delta[0][idx]*sigmoid_der(np.dot(beta.T,z[:,idx]))
        # making the S matrix (3 cross m)
        S=np.matmul(beta,delta)
        for idx in range(3):
            for itr in range(m):
                S[idx][itr]=S[idx][itr]*sigmoid(z[idx][itr])*(1-sigmoid(z[idx][itr]))
        
        #updating the weight vector
        beta-=gamma*np.matmul(z,delta.T)
        alpha-=gamma*np.matmul(S,X[1:,j*m:(j+1)*m].T)
        
    # finding z after every epoch        
    z=np.matmul(alpha.T,X)
    z=z.reshape(1,2*T)
    for idx in range(2*T):
        z[0][idx]=sigmoid(z[0][idx])
    
    z=np.append(np.ones(T),z)
    z=z.reshape(3,T)
    
    #finding the y cap after every epoch 
    y_cap=np.matmul(beta.T,z)   
    for idx in range(T):
        y_cap[0][idx]=sigmoid(y_cap[0][idx])
    
    # storing the errors in an array
    print("epoch:",i+1)
    R_train=np.append(R_train,np.sum((y[:N]-y_cap[0,:N])**2)/N)
    R_test=np.append(R_test,np.sum((y[N:T]-y_cap[0,N:T])**2)/M)
    print("Training error",np.sum((y[:N]-y_cap[0,:N])**2)/N)
    print("Testing error",np.sum((y[N:T]-y_cap[0,N:T])**2)/M)
    
#plotting the results
plt.plot(np.linspace(1,epoch,epoch),R_train[1:], 'r',label='training error')
plt.plot(np.linspace(1,epoch,epoch),R_test[1:],label='testing error')
plt.legend()
plt.grid()
plt.show()
# Out:
# epoch: 1
# Training error 0.25971027805173386
# Testing error 0.25925010368487206
# epoch: 2
# Training error 0.2421217835439332
# Testing error 0.24209522631159247
# epoch: 3
# Training error 0.22687931368681616
# Testing error 0.22703875122571446
# epoch: 4
# Training error 0.21310963717183118
# Testing error 0.21329079323960684
# epoch: 5
# Training error 0.2232426879234128
# Testing error 0.2237936336843178
# epoch: 6
# Training error 0.2483579558441279
# Testing error 0.24943288988789797
# epoch: 7
# Training error 0.2574805777369855
# Testing error 0.2585739326128986
# epoch: 8
# Training error 0.2558151795882352
# Testing error 0.25648612179665087
# epoch: 9
# Training error 0.25276341537871844
# Testing error 0.25297139943976793
# epoch: 10
# Training error 0.25118788098353595
# Testing error 0.2510906800676969
# epoch: 11
# Training error 0.2506915282798384
# Testing error 0.2504389067849176
# epoch: 12
# Training error 0.25062934006139803
# Testing error 0.25031959319667724
# epoch: 13
# Training error 0.2506656046192707
# Testing error 0.2503552878716866
# epoch: 14
# Training error 0.2506859823735517
# Testing error 0.25040384873249527
# epoch: 15
# Training error 0.2506729144633713
# Testing error 0.250430368168898
# epoch: 16
# Training error 0.25063830139019183
# Testing error 0.250436617222049
# epoch: 17
# Training error 0.2505967342441223
# Testing error 0.2504318476727882
# epoch: 18
# Training error 0.2505577631104578
# Testing error 0.25042330930734774
# epoch: 19
# Training error 0.250525509946459
# Testing error 0.2504146488335016
# epoch: 20
# Training error 0.2505004384130838
# Testing error 0.25040686389357925
# epoch: 21
# Training error 0.2504812113169578
# Testing error 0.25039962616544276
# epoch: 22
# Training error 0.25046597731123865
# Testing error 0.25039223078231004
# epoch: 23
# Training error 0.25045304581994515
# Testing error 0.2503840730195106
# epoch: 24
# Training error 0.25044112732358803
# Testing error 0.25037478786743156
# epoch: 25
# Training error 0.25042933634349573
# Testing error 0.2503642179626345
# epoch: 26
# Training error 0.25041709903400244
# Testing error 0.2503523266727076
# epoch: 27
# epoch: 71
# Training error 0.16073934864011893
# Testing error 0.16119716978701995
# epoch: 72
# Training error 0.1630034459438827
# Testing error 0.16341231401338877
# epoch: 73
# Training error 0.16526484026374516
# Testing error 0.16563191389077792
# epoch: 74
# Training error 0.1674873268378542
# Testing error 0.1678204750745542
# epoch: 75
# Training error 0.16963272533037094
# Testing error 0.16994065127175884
# epoch: 76
# Training error 0.17166292714310866
# Testing error 0.17195502988646313
# epoch: 77
# Training error 0.17354493100584653
# Testing error 0.17383085972450393
# epoch: 78
# Training error 0.17525795062973645
# Testing error 0.17554686704111255
# epoch: 79
# Training error 0.17680040529873572
# Testing error 0.177100084519702
# epoch: 80
# Training error 0.17819376710182316
# Testing error 0.17850978547193702
# epoch: 81
# Training error 0.17948114105030563
# Testing error 0.1798164329441152
# epoch: 82
# Training error 0.18072128309622093
# Testing error 0.18107622832188422
# epoch: 83
# Training error 0.18198151955848527
# Testing error 0.18235449345600244
# epoch: 84
# Training error 0.1833332198901628
# Testing error 0.1837213517168105
# epoch: 85
# Training error 0.1848511396258972
# Testing error 0.18525099969550737
# epoch: 86
# Training error 0.1866155001543692
# Testing error 0.18702354912363683
# epoch: 87
# Training error 0.18871465744662538
# Testing error 0.1891274319283192
# epoch: 88
# Training error 0.1912460608434921
# Testing error 0.1916601579541055
# epoch: 89
# Training error 0.19431286918379254
# Testing error 0.19472481579179315
# epoch: 90
# Training error 0.19801306187033726
# Testing error 0.1984191276085404
# epoch: 91
# Training error 0.20241841146747463
# Testing error 0.20281435373755907
# epoch: 92
# Training error 0.20754419549978217
# Testing error 0.2079248294357488
# epoch: 93
# Training error 0.21331755921097412
# Testing error 0.2136760503801137
# epoch: 94
# Training error 0.21955912107602177
# Testing error 0.21988622739131988
# epoch: 95
# Training error 0.22599145537275092
# Testing error 0.22627556184829348
# epoch: 96
# Training error 0.23227694049081704
# Testing error 0.23250594546925354
# epoch: 97
# Training error 0.23807358729110584
# Testing error 0.2382386990445703
# epoch: 98
# Training error 0.24309074149201512
# Testing error 0.24319044488832503
# epoch: 99
# Training error 0.24712945789949073
# Testing error 0.24717115549655252
# epoch: 100
# Training error 0.2501005673180638
# Testing error 0.25009883373784914

# %%
# The follwoing is for XOR
# number of test cases

#initialisation of weight vectors
alpha=np.random.uniform(-4,4,6)
alpha=alpha.reshape(3,2)
beta=np.array([np.random.uniform(-4,4,3)]).T


# The follwoing is for AND
# number of test cases
T=5000
N=int(0.8*T)
M=int(0.2*T)

y=np.ones(T)

# each node in input layer is either 0 or 1 (with some noise)
x1=np.random.randint(0,2,T)
x2=np.random.randint(0,2,T)

#converting to float
x1=x1.astype(float)
x2=x2.astype(float)

#if both nodes are 1 then output node should be 1
for i in range(T):
    if x1[i]==0 and x2[i]==0:
        y[i]=0
    elif x1[i] and x2[i]:
        y[i]=0
        
#adding noise
x1 += np.random.normal(mean, std, T)
x2 += np.random.normal(mean, std, T)

# appending a row of ones, reshaping the matrix
X=np.array([np.ones(T),x1,x2])
X=X.reshape(3,T)


#plotting the input data points
plt.plot(X[1,:],X[2,:],'o',label='pts')
plt.legend()
plt.grid(1)
plt.xlabel('x1')
plt.ylabel('x2') 
plt.show()

#size of mini batch
m=50
#number of epochs
epoch =100
#learning rate
gamma=0.05

#The vector for mse values of training data
R_train=np.empty([1])
#The vector for mse values of testing data
R_test=np.empty([1])

# looping over epoch
for i in range(epoch):
    #looping over the mini batches
    for j in range(N//m):
        #z is sgm(alpha.T * X)
        z=np.matmul(alpha.T,X[:,j*m:(j+1)*m])
        z=z.reshape(1,2*m)
        for idx in range(2*m):
            z[0][idx]=sigmoid(z[0][idx]) 
        
        z=np.append(np.ones(m),z)
        z=z.reshape(3,m)     
        #y_cap is sigmoid of beta.T * z
        y_cap=np.matmul(beta.T,z)
        
        for idx in range(m):
            y_cap[0][idx]=sigmoid(y_cap[0][idx])
        #print(beta,y_cap)
        delta=-2*(y[j*m:(j+1)*m]-y_cap)
        
        #making the delta vector( 1 cross m)
        for idx in range(m):
                delta[0][idx]=delta[0][idx]*sigmoid_der(np.dot(beta.T,z[:,idx]))
        # making the S matrix (3 cross m)
        S=np.matmul(beta,delta)
        for idx in range(3):
            for itr in range(m):
                S[idx][itr]=S[idx][itr]*sigmoid(z[idx][itr])*(1-sigmoid(z[idx][itr]))
        
        #updating the weight vector
        beta-=gamma*np.matmul(z,delta.T)
        alpha-=gamma*np.matmul(S,X[1:,j*m:(j+1)*m].T)
        
    # finding z after every epoch        
    z=np.matmul(alpha.T,X)
    z=z.reshape(1,2*T)
    for idx in range(2*T):
        z[0][idx]=sigmoid(z[0][idx])
    
    z=np.append(np.ones(T),z)
    z=z.reshape(3,T)
    
    #finding the y cap after every epoch 
    y_cap=np.matmul(beta.T,z)   
    for idx in range(T):
        y_cap[0][idx]=sigmoid(y_cap[0][idx])
    
    # storing the errors in an array
    print("epoch:",i+1)
    R_train=np.append(R_train,np.sum((y[:N]-y_cap[0,:N])**2)/N)
    R_test=np.append(R_test,np.sum((y[N:T]-y_cap[0,N:T])**2)/M)
    print("Training error",np.sum((y[:N]-y_cap[0,:N])**2)/N)
    print("Testing error",np.sum((y[N:T]-y_cap[0,N:T])**2)/M)
    
#plotting the results
plt.plot(np.linspace(1,epoch,epoch),R_train[1:], 'r',label='training error')
plt.plot(np.linspace(1,epoch,epoch),R_test[1:],label='testing error')
plt.legend()
plt.grid()
plt.show()
# Out:
# epoch: 1
# Training error 0.21197174026641039
# Testing error 0.212688181838604
# epoch: 2
# Training error 0.18933665872806416
# Testing error 0.1914691315782464
# epoch: 3
# Training error 0.18468086478492557
# Testing error 0.18621857491496477
# epoch: 4
# Training error 0.1984827067144868
# Testing error 0.20054412273166375
# epoch: 5
# Training error 0.21717160025201157
# Testing error 0.21997431852848431
# epoch: 6
# Training error 0.23256659315268388
# Testing error 0.23588995617169184
# epoch: 7
# Training error 0.2437584005902147
# Testing error 0.2473352861792847
# epoch: 8
# Training error 0.25189170355034673
# Testing error 0.25551149296128917
# epoch: 9
# Training error 0.25719680288170116
# Testing error 0.26060654149430845
# epoch: 10
# Training error 0.26044163427876904
# Testing error 0.2634414181608902
# epoch: 11
# Training error 0.26236813375603923
# Testing error 0.26487105882048395
# epoch: 12
# Training error 0.26229386033452623
# Testing error 0.2642367991028403
# epoch: 13
# Training error 0.2588848630885707
# Testing error 0.2602139003266099
# Testing error 0.2506154110333512
# epoch: 58
# Training error 0.25002683977808376
# Testing error 0.25061456792837633
# epoch: 59
# Training error 0.2500257549113526
# Testing error 0.2506138182669249
# epoch: 60
# Training error 0.2500246754510726
# Testing error 0.250613139258478
# epoch: 61
# Training error 0.25002359400357366
# Testing error 0.2506125110858352
# epoch: 62
# Training error 0.25002250401721154
# Testing error 0.25061191648201375
# epoch: 63
# Training error 0.2500213995795797
# Testing error 0.2506113403408163
# epoch: 64
# Training error 0.25002027524840803
# Testing error 0.2506107693692974
# epoch: 65
# Training error 0.25001912591549885
# Testing error 0.2506101917846389
# epoch: 66
# Training error 0.25001794670091004
# Testing error 0.25060959705445834
# epoch: 67
# Training error 0.25001673287360554
# Testing error 0.2506089756776048
# epoch: 68
# Training error 0.25001547979452254
# Testing error 0.25060831900153824
# epoch: 69
# Training error 0.2500141828781564
# Testing error 0.25060761907206164
# epoch: 70
# Training error 0.25001283756914267
# Testing error 0.2506068685112355
# epoch: 71
# Training error 0.25001143933078884
# Testing error 0.2506060604195747
# epoch: 72
# Training error 0.25000998364299803
# Testing error 0.2506051882990056
# epoch: 73
# Training error 0.25000846600748633
# Testing error 0.25060424599346315
# epoch: 74
# Training error 0.2500068819586066
# Testing error 0.2506032276444115
# epoch: 75
# Training error 0.2500052270784365
# Testing error 0.2506021276589369
# epoch: 76
# Training error 0.2500034970150749
# Testing error 0.2506009406883922
# epoch: 77
# Training error 0.25000168750331947
# Testing error 0.2505996616158575
# epoch: 78
# Training error 0.2499997943870743
# Testing error 0.25059828555092606
# epoch: 79
# Training error 0.24999781364297355
# Testing error 0.2505968078305328
# epoch: 80
# Training error 0.24999574140480493
# Testing error 0.25059522402471773
# epoch: 81
# Training error 0.24999357398839073
# Testing error 0.25059352994636386
# epoch: 82
# Training error 0.24999130791663302
# Testing error 0.2505917216640729
# epoch: 83
# Training error 0.24998893994446716
# Testing error 0.25058979551744703
# epoch: 84
# Training error 0.249986467083488
# Testing error 0.2505877481341329
# epoch: 85
# Training error 0.24998388662603124
# Testing error 0.25058557644805945
# epoch: 86
# Training error 0.24998119616850187
# Testing error 0.25058327771836403
# epoch: 87
# Training error 0.24997839363374988
# Testing error 0.2505808495485582
# epoch: 88
# Training error 0.24997547729230116
# Testing error 0.2505782899055294
# epoch: 89
# Training error 0.24997244578225689
# Testing error 0.2505755971380189
# epoch: 90
# Training error 0.24996929812768484
# Testing error 0.2505727699942507
# epoch: 91
# Training error 0.2499660337553338
# Testing error 0.25056980763842157
# epoch: 92
# Training error 0.2499626525095135
# Testing error 0.25056670966579014
# epoch: 93
# Training error 0.24995915466499594
# Testing error 0.2505634761161336
# epoch: 94
# Training error 0.2499555409378065
# Testing error 0.25056010748536506
# epoch: 95
# Training error 0.24995181249379128
# Testing error 0.25055660473513247
# epoch: 96
# Training error 0.24994797095486185
# Testing error 0.2505529693002437
# epoch: 97
# Training error 0.24994401840283859
# Testing error 0.2505492030937884
# epoch: 98
# Training error 0.2499399573808322
# Testing error 0.25054530850985307
# epoch: 99
# Training error 0.24993579089212298
# Testing error 0.2505412884237471
# epoch: 100
# Training error 0.24993152239651797
# Testing error 0.25053714618968814
