# %%
#importing librarier
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
#defining sigmoid function and its derivative
def sigmoid (x):
    return 1/(1+np.exp(-x))

def sigmoid_der (x):
    return sigmoid(x)*(1-sigmoid(x))

#mean , standard deviation for noise
mean=0
std=0.03

# %%
# The follwoing is for XOR
# number of test cases

#initialisation of weight vectors
#alpha=np.random.uniform(-4,4,6)
#alpha=alpha.reshape(3,2)
#beta=np.array([np.random.uniform(-4,4,3)]).T
#print(alpha,beta)
alpha=np.random.uniform(-4,4,6)
alpha=alpha.reshape(3,2)
beta=np.array([np.random.uniform(-4,4,3)]).T
# The follwoing is for AND
# number of test cases
T=1000
N=int(0.8*T)
M=int(0.2*T)

y=np.ones(T)

# each node in input layer is either 0 or 1 (with some noise)
x1=np.random.randint(0,2,T)
x2=np.random.randint(0,2,T)

#converting to float
x1=x1.astype(float)
x2=x2.astype(float)

#if both nodes are 1 then output node should be 1
for i in range(T):
    if x1[i]==0 and x2[i]==0:
        y[i]=0
    elif x1[i] and x2[i]:
        y[i]=0
        
#adding noise
x1 += np.random.normal(mean, std, T)
x2 += np.random.normal(mean, std, T)

# appending a row of ones, reshaping the matrix
X=np.array([np.ones(T),x1,x2])
X=X.reshape(3,T)


#plotting the input data points
plt.plot(X[1,:],X[2,:],'o',label='pts')
plt.legend()
plt.grid(1)
plt.xlabel('x1')
plt.ylabel('x2') 
plt.show()

#size of mini batch
m=50
#number of epochs
epoch =100
#learning rate
gamma=0.05

#The vector for mse values of training data
R_train=np.empty([1])
#The vector for mse values of testing data
R_test=np.empty([1])

# looping over epoch
for i in range(epoch):
    #looping over the mini batches
    for j in range(N//m):
        #z is sgm(alpha.T * X)
        z=np.matmul(alpha.T,X[:,j*m:(j+1)*m])
        z=z.reshape(1,2*m)
        for idx in range(2*m):
            z[0][idx]=sigmoid(z[0][idx]) 
        
        z=np.append(np.ones(m),z)
        z=z.reshape(3,m)     
        #y_cap is sigmoid of beta.T * z
        y_cap=np.matmul(beta.T,z)
        
        for idx in range(m):
            y_cap[0][idx]=sigmoid(y_cap[0][idx])
        #print(beta,y_cap)
        delta=-2*(y[j*m:(j+1)*m]-y_cap)
        
        #making the delta vector( 1 cross m)
        for idx in range(m):
                delta[0][idx]=delta[0][idx]*sigmoid_der(np.dot(beta.T,z[:,idx]))
        # making the S matrix (3 cross m)
        S=np.matmul(beta,delta)
        for idx in range(3):
            for itr in range(m):
                S[idx][itr]=S[idx][itr]*(z[idx][itr])*(1-(z[idx][itr]))
        
        #updating the weight vector
        beta-=gamma*np.matmul(z,delta.T)
        alpha-=gamma*np.matmul(S,X[1:,j*m:(j+1)*m].T)
        
    # finding z after every epoch        
    z=np.matmul(alpha.T,X)
    z=z.reshape(1,2*T)
    for idx in range(2*T):
        z[0][idx]=sigmoid(z[0][idx])
    
    z=np.append(np.ones(T),z)
    z=z.reshape(3,T)
    
    #finding the y cap after every epoch 
    y_cap=np.matmul(beta.T,z)   
    for idx in range(T):
        y_cap[0][idx]=sigmoid(y_cap[0][idx])
    
    # storing the errors in an array
    print("epoch:",i+1)
    R_train=np.append(R_train,np.sum((y[:N]-y_cap[0,:N])**2)/N)
    R_test=np.append(R_test,np.sum((y[N:T]-y_cap[0,N:T])**2)/M)
    print("Training error",np.sum((y[:N]-y_cap[0,:N])**2)/N)
    print("Testing error",np.sum((y[N:T]-y_cap[0,N:T])**2)/M)
    print(alpha,beta)
#print("Observation: Saddle point is reached")    
#plotting the results
plt.plot(np.linspace(1,epoch,epoch),R_train[1:], 'r',label='training error')
plt.plot(np.linspace(1,epoch,epoch),R_test[1:],label='testing error')
plt.legend()
plt.grid()
plt.show()
# Out:
# epoch: 1
# Training error 0.21878200309742915
# Testing error 0.2327073535725109
# [[-3.09824245 -1.6076515 ]
#  [-0.80972125 -3.94182777]
#  [-2.3860655   1.59306906]] [[-0.27428512]
#  [-4.00093018]
#  [ 3.24873671]]
# epoch: 2
# Training error 0.2114260627375028
# Testing error 0.22044163575909587
# [[-3.09824245 -1.6076515 ]
#  [-1.02380493 -3.9402429 ]
#  [-2.47709974  2.01355164]] [[-0.55420898]
#  [-4.04061854]
#  [ 3.22368342]]
# epoch: 3
# Training error 0.20902761108058585
# Testing error 0.21757345561072391
# [[-3.09824245 -1.6076515 ]
#  [-1.20761195 -3.93964952]
#  [-2.60924853  2.26953683]] [[-0.62222537]
#  [-4.08293102]
#  [ 3.19278604]]
# epoch: 4
# Training error 0.20782696754502222
# Testing error 0.2161798818250824
# [[-3.09824245 -1.6076515 ]
#  [-1.36665807 -3.93955546]
#  [-2.77344858  2.41988698]] [[-0.65127072]
#  [-4.12969488]
#  [ 3.14553832]]
# epoch: 5
# Training error 0.20703605579408776
# Testing error 0.21531768087487235
# [[-3.09824245 -1.6076515 ]
#  [-1.50687122 -3.93991796]
#  [-2.95914802  2.51277478]] [[-0.66144439]
#  [-4.18036086]
#  [ 3.092919  ]]
# epoch: 6
# Training error 0.20642293861128272
# Testing error 0.21468946246516082
# [[-3.09824245 -1.6076515 ]
#  [-1.6323922  -3.9405849 ]
#  [-3.15893772  2.57317898]] [[-0.66235745]
#  [-4.23437814]
#  [ 3.04109856]]
# epoch: 7
# Training error 0.2059098459735437
# Testing error 0.2141866461752736
# [[-3.09824245 -1.6076515 ]
#  [-1.74614923 -3.94141014]
#  [-3.36801105  2.61449146]] [[-0.65887888]
#  [-4.29125829]
#  [ 2.9931347 ]]
# epoch: 8
# Training error 0.20546475971622813
# Testing error 0.21376219977866598
# [[-3.09824245 -1.6076515 ]
#  [-1.85027666 -3.94228523]
#  [-3.5833427   2.64410331]] [[-0.65352708]
#  [-4.35058189]
#  [ 2.9503075 ]]
# epoch: 9
# Training error 0.20507064595782828
# Testing error 0.2133917135946701
# [[-3.09824245 -1.6076515 ]
#  [-1.94637741 -3.94314047]
#  [-3.80303443  2.66619529]] [[-0.64759841]
#  [-4.41199336]
#  [ 2.91292077]]
# epoch: 10
# Training error 0.2047163052882381
# Testing error 0.21306045804446533
# [[-3.09824245 -1.6076515 ]
#  [-2.03568665 -3.94393689]
#  [-4.02587638  2.68319683]] [[-0.64173831]
#  [-4.47519329]
#  [ 2.88076735]]
# epoch: 11
# Training error 0.2043934749125623
# Testing error 0.2127586076110378
# [[-3.09824245 -1.6076515 ]
#  [-2.11917675 -3.94465735]
#  [-4.2510743   2.69656879]] [[-0.63624386]
#  [-4.53993028]
#  [ 2.85339576]]
# epoch: 12
# Training error 0.2040957709190533
# Testing error 0.21247921799220315
# [[-3.09824245 -1.6076515 ]
#  [-2.19762702 -3.94529894]
#  [-4.47808599  2.70722874]] [[-0.63122762]
#  [-4.60599337]
#  [ 2.83026061]]
# epoch: 13
# Training error 0.20381818770784094
# Testing error 0.2122172209199273
# [[-3.09824245 -1.6076515 ]
#  [-2.2716716  -3.94586742]
#  [-4.70652496  2.71578369]] [[-0.62670721]
#  [-4.67320527]
#  [ 2.81080475]]
# epoch: 14
# Training error 0.20355678478896916
# Testing error 0.21196884600890406
# [[-3.09824245 -1.6076515 ]
#  [-2.34183327 -3.94637336]
#  [-4.93610367  2.72265816]] [[-0.62265404]
#  [-4.74141655]
#  [ 2.79450167]]
# epoch: 15
# Training error 0.2033084554438263
# Testing error 0.21173125128330283
# [[-3.09824245 -1.6076515 ]
#  [-2.40854794 -3.94682952]
#  [-5.1666001   2.72816511]] [[-0.61901971]
#  [-4.81050072]
#  [ 2.78087502]]
# epoch: 16
# Training error 0.2030707456253704
# Testing error 0.2115022715712689
# [[-3.09824245 -1.6076515 ]
#  [-2.47218274 -3.94724924]
#  [-5.39783749  2.7325458 ]] [[-0.61574988]
#  [-4.88035022]
#  [ 2.76950529]]
# epoch: 17
# Training error 0.20284171092659478
# Testing error 0.21128024107541776
# [[-3.09824245 -1.6076515 ]
#  [-2.53304967 -3.94764547]
#  [-5.62967193  2.73599259]] [[-0.61279134]
#  [-4.95087312]
#  [ 2.76002948]]
# epoch: 18
# Training error 0.20261980429582363
# Testing error 0.21106386585287104
# [[-3.09824245 -1.6076515 ]
#  [-2.59141598 -3.9480302 ]
#  [-5.8619843   2.73866242]] [[-0.6100953 ]
#  [-5.02199037]
#  [ 2.75213721]]
# epoch: 19
# Training error 0.20240378859416516
# Testing error 0.21085213114340542
# [[-3.09824245 -1.6076515 ]
#  [-2.64751227 -3.94841426]
#  [-6.09467488  2.74068527]] [[-0.60761859]
#  [-5.09363365]
#  [ 2.74556537]]
# epoch: 20
# Training error 0.20219266891579118
# Testing error 0.2106442335126447
# [[-3.09824245 -1.6076515 ]
#  [-2.70153885 -3.94880717]
#  [-6.3276595   2.74216969]] [[-0.60532391]
#  [-5.16574355]
#  [ 2.74009225]]
# epoch: 21
# Training error 0.20198564038643202
# Testing error 0.21043953085675432
# [[-3.09824245 -1.6076515 ]
#  [-2.75367071 -3.94921721]
#  [-6.56086674  2.74320672]] [[-0.60317949]
#  [-5.23826814]
#  [ 2.73553185]]
# epoch: 22
# Training error 0.20178204794047908
# Testing error 0.21023750534817232
# [[-3.09824245 -1.6076515 ]
#  [-2.80406163 -3.94965149]
#  [-6.79423567  2.74387286]] [[-0.60115851]
#  [-5.31116173]
#  [ 2.73172865]]
# epoch: 23
# Training error 0.20158135529503285
# Testing error 0.21003773580283577
# [[-3.09824245 -1.6076515 ]
#  [-2.85284742 -3.95011606]
#  [-7.02771415  2.74423239]] [[-0.5992385 ]
#  [-5.38438393]
#  [ 2.72855293]]
# epoch: 24
# Training error 0.2013831209535542
# Testing error 0.20983987693655579
# [[-3.09824245 -1.6076515 ]
#  [-2.90014857 -3.95061603]
#  [-7.26125736  2.74433928]] [[-0.59740073]
#  [-5.45789882]
#  [ 2.7258967 ]]
# epoch: 25
# Training error 0.20118697957338058
# Testing error 0.20964364368162564
# [[-3.09824245 -1.6076515 ]
#  [-2.94607247 -3.95115568]
#  [-7.49482662  2.74423882]] [[-0.59562963]
#  [-5.5316743 ]
#  [ 2.72367019]]
# epoch: 26
# Training error 0.20099262742809795
# Testing error 0.20944879923874457
# [[-3.09824245 -1.6076515 ]
#  [-2.99071522 -3.95173856]
#  [-7.72838839  2.74396893]] [[-0.5939123 ]
#  [-5.60568153]
#  [ 2.72179887]]
# epoch: 27
# Training error 0.20079981100286715
# Testing error 0.2092551459014761
# [[-3.09824245 -1.6076515 ]
#  [-3.03416316 -3.95236762]
#  [-7.96191347  2.74356133]] [[-0.59223809]
#  [-5.67989445]
#  [ 2.72022089]]
# epoch: 28
# Training error 0.2006083179951548
# Testing error 0.20906251795116662
# [[-3.09824245 -1.6076515 ]
#  [-3.07649409 -3.95304529]
#  [-8.19537626  2.74304253]] [[-0.5905982 ]
#  [-5.75428941]
#  [ 2.71888501]]
# epoch: 29
# Training error 0.20041797017052002
# Testing error 0.20887077610826277
# [[-3.09824245 -1.6076515 ]
#  [-3.11777843 -3.9537735 ]
#  [-8.42875421  2.74243464]] [[-0.58898537]
#  [-5.82884486]
#  [ 2.71774876]]
# epoch: 30
# Training error 0.20022861765637404
# Testing error 0.208679803161846
# [[-3.09824245 -1.6076515 ]
#  [-3.15808004 -3.95455382]
#  [-8.66202731  2.74175609]] [[-0.58739366]
#  [-5.90354102]
#  [ 2.71677699]]
# epoch: 31
# Training error 0.2000401343566007
# Testing error 0.20848950049765874
# [[-3.09824245 -1.6076515 ]
#  [-3.19745706 -3.95538748]
#  [-8.89517771  2.74102221]] [[-0.58581818]
#  [-5.97835972]
#  [ 2.71594061]]
# epoch: 32
# Training error 0.19985241424490052
# Testing error 0.2082997853164766
# [[-3.09824245 -1.6076515 ]
#  [-3.23596254 -3.95627539]
#  [-9.12818935  2.74024575]] [[-0.58425493]
#  [-6.05328411]
#  [ 2.71521557]]
# epoch: 33
# Training error 0.1996653683510331
# Testing error 0.20811058838692653
# [[-3.09824245 -1.6076515 ]
#  [-3.27364503 -3.95721821]
#  [-9.36104766  2.73943729]] [[-0.58270063]
#  [-6.12829859]
#  [ 2.71458198]]
# epoch: 34
# Training error 0.1994789222965462
# Testing error 0.20792185221516285
# [[-3.09824245 -1.6076515 ]
#  [-3.31054905 -3.95821639]
#  [-9.59373939  2.7386056 ]] [[-0.58115264]
#  [-6.20338856]
#  [ 2.7140234 ]]
# epoch: 35
# Training error 0.19929301426865528
# Testing error 0.20773352954205826
# [[-3.09824245 -1.6076515 ]
#  [-3.34671556 -3.95927015]
#  [-9.82625235  2.73775794]] [[-0.5796088 ]
#  [-6.27854039]
#  [ 2.71352627]]
# epoch: 36
# Training error 0.19910759334530842
# Testing error 0.20754558209950985
# [[ -3.09824245  -1.6076515 ]
#  [ -3.38218228  -3.96037954]
#  [-10.05857528   2.7369003 ]] [[-0.57806736]
#  [-6.35374122]
#  [ 2.71307939]]
# epoch: 37
# Training error 0.19892261810309253
# Testing error 0.2073579795730916
# [[ -3.09824245  -1.6076515 ]
#  [ -3.41698406  -3.96154445]
#  [-10.29069772   2.73603762]] [[-0.57652695]
#  [-6.42897894]
#  [ 2.71267353]]
# epoch: 38
# Training error 0.1987380554539425
# Testing error 0.20717069873003063
# [[ -3.09824245  -1.6076515 ]
#  [ -3.45115313  -3.9627646 ]
#  [-10.52260988   2.73517395]] [[-0.57498646]
#  [-6.50424205]
#  [ 2.71230111]]
# epoch: 39
# Training error 0.1985538796676782
# Testing error 0.20698372268037007
# [[ -3.09824245  -1.6076515 ]
#  [ -3.48471938  -3.96403957]
#  [-10.75430256   2.7343126 ]] [[-0.57344501]
#  [-6.57951963]
#  [ 2.71195585]]
# epoch: 40
# Training error 0.1983700715460003
# Testing error 0.206797040245961
# [[ -3.09824245  -1.6076515 ]
#  [ -3.51771056  -3.96536884]
#  [-10.98576711   2.73345626]] [[-0.57190195]
#  [-6.65480125]
#  [ 2.71163263]]
# epoch: 41
# Training error 0.1981866177203098
# Testing error 0.20661064541712867
# [[ -3.09824245  -1.6076515 ]
#  [ -3.5501525   -3.96675172]
#  [-11.21699532   2.7326071 ]] [[-0.57035678]
#  [-6.73007691]
#  [ 2.71132725]]
# epoch: 42
# Training error 0.19800351005102543
# Testing error 0.2064245368808901
# [[ -3.09824245  -1.6076515 ]
#  [ -3.58206924  -3.96818744]
#  [-11.44797939   2.73176684]] [[-0.56880912]
#  [-6.80533704]
#  [ 2.71103625]]
# epoch: 43
# Training error 0.19782074511027403
# Testing error 0.20623871760774126
# [[ -3.09824245  -1.6076515 ]
#  [ -3.61348324  -3.9696751 ]
#  [-11.67871194   2.73093685]] [[-0.56725874]
#  [-6.88057238]
#  [ 2.71075684]]
# epoch: 44
# Training error 0.19763832373318113
# Testing error 0.2060531944865062
# [[ -3.09824245  -1.6076515 ]
#  [ -3.64441547  -3.9712137 ]
#  [-11.9091859    2.73011818]] [[-0.56570548]
#  [-6.95577401]
#  [ 2.71048673]]
# epoch: 45
# Training error 0.19745625062567407
# Testing error 0.20586797799869522
# [[ -3.09824245  -1.6076515 ]
#  [ -3.67488557  -3.97280212]
#  [-12.13939455   2.72931162]] [[-0.56414927]
#  [-7.03093328]
#  [ 2.7102241 ]]
# epoch: 46
# Training error 0.19727453401887374
# Testing error 0.20568308192538423
# [[ -3.09824245  -1.6076515 ]
#  [ -3.70491192  -3.97443918]
#  [-12.36933149   2.72851774]] [[-0.56259011]
#  [-7.10604179]
#  [ 2.70996746]]
# epoch: 47
# Training error 0.1970931853619059
# Testing error 0.20549852308088276
# [[ -3.09824245  -1.6076515 ]
#  [ -3.7345118   -3.97612355]
#  [-12.5989906    2.7277369 ]] [[-0.56102806]
#  [-7.18109138]
#  [ 2.70971564]]
# epoch: 48
# Training error 0.19691221904638787
# Testing error 0.20531432106847766
# [[ -3.09824245  -1.6076515 ]
#  [ -3.7637014   -3.97785386]
#  [-12.82836606   2.72696931]] [[-0.55946323]
#  [-7.25607408]
#  [ 2.70946772]]
# epoch: 49
# Training error 0.19673165215701938
# Testing error 0.20513049805437164
# [[ -3.09824245  -1.6076515 ]
#  [ -3.79249598  -3.97962861]
#  [-13.05745233   2.72621506]] [[-0.55789578]
#  [-7.33098211]
#  [ 2.70922299]]
# epoch: 50
# Training error 0.1965515042436641
# Testing error 0.2049470785566168
# [[ -3.09824245  -1.6076515 ]
#  [ -3.82090988  -3.98144624]
#  [-13.28624417   2.7254741 ]] [[-0.55632589]
#  [-7.40580786]
#  [ 2.70898091]]
# epoch: 51
# Training error 0.1963717971111057
# Testing error 0.2047640892464152
# [[ -3.09824245  -1.6076515 ]
#  [ -3.84895663  -3.98330509]
#  [-13.51473659   2.72474627]] [[-0.55475379]
#  [-7.48054388]
#  [ 2.70874108]]
# epoch: 52
# Training error 0.1961925546233223
# Testing error 0.20458155875962525
# [[ -3.09824245  -1.6076515 ]
#  [ -3.876649    -3.98520344]
#  [-13.74292489   2.72403133]] [[-0.55317972]
#  [-7.55518286]
#  [ 2.70850323]]
# epoch: 53
# Training error 0.1960138025196749
# Testing error 0.20439951751671526
# [[ -3.09824245  -1.6076515 ]
#  [ -3.90399903  -3.98713947]
#  [-13.97080465   2.72332897]] [[-0.55160397]
#  [-7.62971763]
#  [ 2.70826719]]
# epoch: 54
# Training error 0.19583556824086787
# Testing error 0.20421799754973724
# [[ -3.09824245  -1.6076515 ]
#  [ -3.93101811  -3.98911131]
#  [-14.19837172   2.7226388 ]] [[-0.55002682]
#  [-7.70414114]
#  [ 2.70803288]]
# epoch: 55
# Training error 0.1956578807629319
# Testing error 0.2040370323351824
# [[ -3.09824245  -1.6076515 ]
#  [ -3.95771701  -3.99111699]
#  [-14.42562226   2.72196038]] [[-0.5484486 ]
#  [-7.77844644]
#  [ 2.70780028]]
# epoch: 56
# Training error 0.1954807704378088
# Testing error 0.20385665663182273
# [[ -3.09824245  -1.6076515 ]
#  [ -3.98410594  -3.99315452]
#  [-14.65255267   2.72129322]] [[-0.54686964]
#  [-7.85262673]
#  [ 2.70756943]]
# epoch: 57
# Training error 0.195304268839401
# Testing error 0.20367690632285296
# [[ -3.09824245  -1.6076515 ]
#  [ -4.01019456  -3.99522181]
#  [-14.87915966   2.72063677]] [[-0.54529028]
#  [-7.9266753 ]
#  [ 2.70734042]]
# epoch: 58
# Training error 0.19512840861418865
# Testing error 0.20349781826182833
# [[ -3.09824245  -1.6076515 ]
#  [ -4.03599203  -3.99731673]
#  [-15.10544024   2.71999046]] [[-0.54371088]
#  [-8.00058553]
#  [ 2.7071134 ]]
# epoch: 59
# Training error 0.19495322333572454
# Testing error 0.20331943012204995
# [[ -3.09824245  -1.6076515 ]
#  [ -4.06150707  -3.9994371 ]
#  [-15.33139168   2.71935366]] [[-0.54213182]
#  [-8.07435093]
#  [ 2.70688853]]
# epoch: 60
# Training error 0.1947787473624949
# Testing error 0.20314178024918242
# [[ -3.09824245  -1.6076515 ]
#  [ -4.08674794  -4.00158068]
#  [-15.55701157   2.71872575]] [[-0.54055348]
#  [-8.14796512]
#  [ 2.70666602]]
# epoch: 61
# Training error 0.19460501569878716
# Testing error 0.20296490751700666
# [[ -3.09824245  -1.6076515 ]
#  [ -4.1117225   -4.00374521]
#  [-15.78229778   2.71810604]] [[-0.53897626]
#  [-8.22142178]
#  [ 2.70644608]]
# epoch: 62
# Training error 0.19443206385833836
# Testing error 0.2027888511863084
# [[ -3.09824245  -1.6076515 ]
#  [ -4.13643822  -4.00592838]
#  [-16.00724847   2.71749384]] [[-0.53740054]
#  [-8.29471475]
#  [ 2.70622897]]
# epoch: 63
# Training error 0.19425992773065215
# Testing error 0.20261365076698717
# [[ -3.09824245  -1.6076515 ]
#  [ -4.16090223  -4.00812783]
#  [-16.23186212   2.71688846]] [[-0.53582674]
#  [-8.36783793]
#  [ 2.70601493]]
# epoch: 64
# Training error 0.1940886434499687
# Testing error 0.20243934588354268
# [[ -3.09824245  -1.6076515 ]
#  [ -4.18512131  -4.01034121]
#  [-16.45613749   2.71628915]] [[-0.53425525]
#  [-8.44078536]
#  [ 2.70580426]]
# epoch: 65
# Training error 0.1939182472669569
# Testing error 0.20226597614415112
# [[ -3.09824245  -1.6076515 ]
#  [ -4.20910193  -4.01256613]
#  [-16.68007364   2.71569519]] [[-0.5326865 ]
#  [-8.51355118]
#  [ 2.70559723]]
# epoch: 66
# Training error 0.19374877542326657
# Testing error 0.20209358101359187
# [[ -3.09824245  -1.6076515 ]
#  [ -4.23285026  -4.01480017]
#  [-16.90366993   2.71510582]] [[-0.5311209 ]
#  [-8.58612964]
#  [ 2.70539414]]
# epoch: 67
# Training error 0.19358026402913991
# Testing error 0.20192219969031966
# [[ -3.09824245  -1.6076515 ]
#  [ -4.25637219  -4.01704094]
#  [-17.12692601   2.7145203 ]] [[-0.52955887]
#  [-8.6585151 ]
#  [ 2.70519529]]
# epoch: 68
# Training error 0.19341274894432436
# Testing error 0.20175187098800113
# [[ -3.09824245  -1.6076515 ]
#  [ -4.27967337  -4.01928601]
#  [-17.34984184   2.71393785]] [[-0.52800081]
#  [-8.73070207]
#  [ 2.70500099]]
# epoch: 69
# Training error 0.19324626566257172
# Testing error 0.20158263322185113
# [[ -3.09824245  -1.6076515 ]
#  [ -4.30275918  -4.02153296]
#  [-17.57241765   2.71335773]] [[-0.52644715]
#  [-8.80268516]
#  [ 2.70481154]]
# epoch: 70
# Training error 0.19308084920003196
# Testing error 0.20141452410010807
# [[ -3.09824245  -1.6076515 ]
#  [ -4.32563478  -4.0237794 ]
#  [-17.79465397   2.71277917]] [[-0.5248983 ]
#  [-8.87445912]
#  [ 2.70462726]]
# epoch: 71
# Training error 0.19291653398787167
# Testing error 0.20124758062098486
# [[ -3.09824245  -1.6076515 ]
#  [ -4.3483051   -4.02602293]
#  [-18.01655161   2.71220141]] [[-0.52335465]
#  [-8.94601882]
#  [ 2.70444845]]
# epoch: 72
# Training error 0.19275335376945688
# Testing error 0.20108183897542162
# [[ -3.09824245  -1.6076515 ]
#  [ -4.37077489  -4.02826118]
#  [-18.23811168   2.71162371]] [[-0.52181663]
#  [-9.01735929]
#  [ 2.70427542]]
# epoch: 73
# Training error 0.19259134150244195
# Testing error 0.20091733445594592
# [[ -3.09824245  -1.6076515 ]
#  [ -4.39304868  -4.0304918 ]
#  [-18.45933554   2.71104531]] [[-0.52028462]
#  [-9.08847569]
#  [ 2.70410848]]
# epoch: 74
# Training error 0.19243052926610343
# Testing error 0.20075410137192187
# [[ -3.09824245  -1.6076515 ]
#  [ -4.41513085  -4.03271248]
#  [-18.68022483   2.71046547]] [[-0.51875902]
#  [-9.15936332]
#  [ 2.70394793]]
# epoch: 75
# Training error 0.1922709481742435
# Testing error 0.20059217297143606
# [[ -3.09824245  -1.6076515 ]
#  [ -4.43702558  -4.03492094]
#  [-18.90078147   2.70988347]] [[-0.5172402 ]
#  [-9.23001764]
#  [ 2.70379406]]
# epoch: 76
# Training error 0.19211262829397208
# Testing error 0.2004315813700328
# [[ -3.09824245  -1.6076515 ]
#  [ -4.45873689  -4.03711493]
#  [-19.1210076    2.7092986 ]] [[-0.51572855]
#  [-9.30043426]
#  [ 2.70364717]]
# epoch: 77
# Training error 0.19195559857065014
# Testing error 0.2002723574864681
# [[ -3.09824245  -1.6076515 ]
#  [ -4.48026868  -4.03929228]
#  [-19.34090566   2.70871014]] [[-0.51422442]
#  [-9.37060895]
#  [ 2.70350754]]
# epoch: 78
# Training error 0.1917998867592507
# Testing error 0.20011453098560528
# [[ -3.09824245  -1.6076515 ]
#  [ -4.50162468  -4.04145084]
#  [-19.56047829   2.70811743]] [[-0.51272817]
#  [-9.44053765]
#  [ 2.70337544]]
# epoch: 79
# Training error 0.19164551936235646
# Testing error 0.19995813022852948
# [[ -3.09824245  -1.6076515 ]
#  [ -4.52280849  -4.04358853]
#  [-19.77972839   2.70751979]] [[-0.51124015]
#  [-9.51021644]
#  [ 2.70325114]]
# epoch: 80
# Training error 0.19149252157497762
# Testing error 0.19980318222990515
# [[ -3.09824245  -1.6076515 ]
#  [ -4.54382359  -4.04570332]
#  [-19.99865908   2.70691656]] [[-0.50976067]
#  [-9.57964159]
#  [ 2.70313491]]
# epoch: 81
# Training error 0.1913409172363313
# Testing error 0.19964971262254955
# [[ -3.09824245  -1.6076515 ]
#  [ -4.56467333  -4.04779326]
#  [-20.21727369   2.70630713]] [[-0.50829006]
#  [-9.64880952]
#  [ 2.70302698]]
# epoch: 82
# Training error 0.19119072878867935
# Testing error 0.19949774562914624
# [[ -3.09824245  -1.6076515 ]
#  [ -4.58536096  -4.04985645]
#  [-20.43557577   2.70569087]] [[-0.50682861]
#  [-9.71771685]
#  [ 2.70292759]]
# epoch: 83
# Training error 0.19104197724327604
# Testing error 0.19934730404096734
# [[ -3.09824245  -1.6076515 ]
#  [ -4.60588961  -4.05189108]
#  [-20.65356907   2.70506721]] [[-0.50537662]
#  [-9.78636034]
#  [ 2.70283698]]
# epoch: 84
# Training error 0.19089468215342947
# Testing error 0.19919840920342893
# [[ -3.09824245  -1.6076515 ]
#  [ -4.62626234  -4.05389539]
#  [-20.87125751   2.70443558]] [[-0.50393436]
#  [-9.85473694]
#  [ 2.70275534]]
# epoch: 85
# Training error 0.1907488615946327
# Testing error 0.19905108100825278
# [[ -3.09824245  -1.6076515 ]
#  [ -4.64648207  -4.05586772]
#  [-21.08864522   2.70379544]] [[-0.50250209]
#  [-9.92284377]
#  [ 2.70268289]]
# epoch: 86
# Training error 0.19060453215167306
# Testing error 0.1989053378919673
# [[ -3.09824245  -1.6076515 ]
#  [ -4.66655167  -4.05780648]
#  [-21.30573646   2.70314627]] [[-0.50108004]
#  [-9.99067813]
#  [ 2.70261981]]
# epoch: 87
# Training error 0.19046170891258093
# Testing error 0.19876119684043883
# [[ -3.09824245  -1.6076515 ]
#  [ -4.68647391  -4.05971015]
#  [-21.52253569   2.70248758]] [[ -0.49966844]
#  [-10.05823748]
#  [  2.70256627]]
# epoch: 88
# Training error 0.19032040546923493
# Testing error 0.19861867339908948
# [[ -3.09824245  -1.6076515 ]
#  [ -4.70625149  -4.0615773 ]
#  [-21.73904749   2.70181891]] [[ -0.49826751]
#  [-10.12551948]
#  [  2.70252244]]
# epoch: 89
# Training error 0.19018063392439577
# Testing error 0.19847778168842659
# [[ -3.09824245  -1.6076515 ]
#  [ -4.72588702  -4.06340659]
#  [-21.95527659   2.70113982]] [[ -0.49687743]
#  [-10.19252192]
#  [  2.70248846]]
# epoch: 90
# Training error 0.1900424049049023
# Testing error 0.19833853442448454
# [[ -3.09824245  -1.6076515 ]
#  [ -4.74538306  -4.06519674]
#  [-22.17122785   2.70044988]] [[ -0.49549838]
#  [-10.2592428 ]
#  [  2.70246447]]
# epoch: 91
# Training error 0.1899057275807246
# Testing error 0.19820094294375726
# [[ -3.09824245  -1.6076515 ]
#  [ -4.76474209  -4.06694659]
#  [-22.38690623   2.69974872]] [[ -0.49413053]
#  [-10.32568027]
#  [  2.70245058]]
# epoch: 92
# Training error 0.18977060968953668
# Testing error 0.19806501723218745
# [[ -3.09824245  -1.6076515 ]
#  [ -4.78396654  -4.06865502]
#  [-22.60231682   2.69903598]] [[ -0.49277401]
#  [-10.39183263]
#  [  2.70244691]]
# epoch: 93
# Training error 0.18963705756644017
# Testing error 0.19793076595776832
# [[ -3.09824245  -1.6076515 ]
#  [ -4.80305877  -4.07032102]
#  [-22.8174648    2.6983113 ]] [[ -0.49142895]
#  [-10.45769838]
#  [  2.70245353]]
# epoch: 94
# Training error 0.1895050761784475
# Testing error 0.19779819650630956
# [[ -3.09824245  -1.6076515 ]
#  [ -4.82202108  -4.07194366]
#  [-23.03235544   2.6975744 ]] [[ -0.49009548]
#  [-10.52327613]
#  [  2.70247054]]
# epoch: 95
# Training error 0.18937466916330956
# Testing error 0.19766731501992205
# [[ -3.09824245  -1.6076515 ]
#  [ -4.84085575  -4.07352209]
#  [-23.24699409   2.69682497]] [[ -0.48877368]
#  [-10.58856468]
#  [  2.70249799]]
# epoch: 96
# Training error 0.18924583887225996
# Testing error 0.19753812643778168
# [[ -3.09824245  -1.6076515 ]
#  [ -4.85956496  -4.07505552]
#  [-23.46138615   2.69606277]] [[ -0.48746364]
#  [-10.65356297]
#  [  2.70253593]]
# epoch: 97
# Training error 0.1891185864162334
# Testing error 0.19741063453874425
# [[ -3.09824245  -1.6076515 ]
#  [ -4.8781509   -4.07654327]
#  [-23.67553712   2.69528755]] [[ -0.48616543]
#  [-10.71827009]
#  [  2.7025844 ]]
# epoch: 98
# Training error 0.18899291171511234
# Testing error 0.19728484198539845
# [[ -3.09824245  -1.6076515 ]
#  [ -4.89661567  -4.0779847 ]
#  [-23.8894525    2.69449911]] [[ -0.48487909]
#  [-10.78268525]
#  [  2.70264342]]
# epoch: 99
# Training error 0.18886881354955165
# Testing error 0.19716075036916383
# [[ -3.09824245  -1.6076515 ]
#  [ -4.91496134  -4.07937928]
#  [-24.10313789   2.69369726]] [[ -0.48360468]
#  [-10.84680782]
#  [  2.70271301]]
# epoch: 100
# Training error 0.188746289614935
# Testing error 0.19703836025606292
# [[ -3.09824245  -1.6076515 ]
#  [ -4.93318997  -4.08072651]
#  [-24.31659888   2.69288183]] [[ -0.48234222]
#  [-10.9106373 ]
#  [  2.70279316]]

# %%
# The follwoing is for XOR
# number of test cases

#initialisation of weight vectors
alpha=np.random.uniform(-4,4,6)
alpha=alpha.reshape(3,2)
beta=np.array([np.random.uniform(-4,4,3)]).T


# The follwoing is for AND
# number of test cases
T=2500
N=int(0.8*T)
M=int(0.2*T)

y=np.ones(T)

# each node in input layer is either 0 or 1 (with some noise)
x1=np.random.randint(0,2,T)
x2=np.random.randint(0,2,T)

#converting to float
x1=x1.astype(float)
x2=x2.astype(float)

#if both nodes are 1 then output node should be 1
for i in range(T):
    if x1[i]==0 and x2[i]==0:
        y[i]=0
    elif x1[i] and x2[i]:
        y[i]=0
        
#adding noise
x1 += np.random.normal(mean, std, T)
x2 += np.random.normal(mean, std, T)

# appending a row of ones, reshaping the matrix
X=np.array([np.ones(T),x1,x2])
X=X.reshape(3,T)


#plotting the input data points
plt.plot(X[1,:],X[2,:],'o',label='pts')
plt.legend()
plt.grid(1)
plt.xlabel('x1')
plt.ylabel('x2') 
plt.show()

#size of mini batch
m=50
#number of epochs
epoch =100
#learning rate
gamma=0.05

#The vector for mse values of training data
R_train=np.empty([1])
#The vector for mse values of testing data
R_test=np.empty([1])

# looping over epoch
for i in range(epoch):
    #looping over the mini batches
    for j in range(N//m):
        #z is sgm(alpha.T * X)
        z=np.matmul(alpha.T,X[:,j*m:(j+1)*m])
        z=z.reshape(1,2*m)
        for idx in range(2*m):
            z[0][idx]=sigmoid(z[0][idx]) 
        
        z=np.append(np.ones(m),z)
        z=z.reshape(3,m)     
        #y_cap is sigmoid of beta.T * z
        y_cap=np.matmul(beta.T,z)
        
        for idx in range(m):
            y_cap[0][idx]=sigmoid(y_cap[0][idx])
        #print(beta,y_cap)
        delta=-2*(y[j*m:(j+1)*m]-y_cap)
        
        #making the delta vector( 1 cross m)
        for idx in range(m):
                delta[0][idx]=delta[0][idx]*sigmoid_der(np.dot(beta.T,z[:,idx]))
        # making the S matrix (3 cross m)
        S=np.matmul(beta,delta)
        for idx in range(3):
            for itr in range(m):
                S[idx][itr]=S[idx][itr]*sigmoid(z[idx][itr])*(1-sigmoid(z[idx][itr]))
        
        #updating the weight vector
        beta-=gamma*np.matmul(z,delta.T)
        alpha-=gamma*np.matmul(S,X[1:,j*m:(j+1)*m].T)
        
    # finding z after every epoch        
    z=np.matmul(alpha.T,X)
    z=z.reshape(1,2*T)
    for idx in range(2*T):
        z[0][idx]=sigmoid(z[0][idx])
    
    z=np.append(np.ones(T),z)
    z=z.reshape(3,T)
    
    #finding the y cap after every epoch 
    y_cap=np.matmul(beta.T,z)   
    for idx in range(T):
        y_cap[0][idx]=sigmoid(y_cap[0][idx])
    
    # storing the errors in an array
    print("epoch:",i+1)
    R_train=np.append(R_train,np.sum((y[:N]-y_cap[0,:N])**2)/N)
    R_test=np.append(R_test,np.sum((y[N:T]-y_cap[0,N:T])**2)/M)
    print("Training error",np.sum((y[:N]-y_cap[0,:N])**2)/N)
    print("Testing error",np.sum((y[N:T]-y_cap[0,N:T])**2)/M)
    print(alpha,beta)
#plotting the results
plt.plot(np.linspace(1,epoch,epoch),R_train[1:], 'r',label='training error')
plt.plot(np.linspace(1,epoch,epoch),R_test[1:],label='testing error')
plt.legend()
plt.grid()
plt.show()
# Out:
# epoch: 1
# Training error 0.253277567657006
# Testing error 0.2499008500137495
# [[ 2.95083013  2.01214938]
#  [-2.33943887  0.13359261]
#  [-3.64689348  1.66206205]] [[ 1.7701135 ]
#  [-0.38873012]
#  [-1.93191401]]
# epoch: 2
# Training error 0.25166614884052924
# Testing error 0.24985699898401117
# [[ 2.89506401  2.01595524]
#  [-2.29066595  0.12637577]
#  [-3.74406901  1.59386923]] [[ 1.79389093]
#  [-0.56791366]
#  [-1.84300217]]
# epoch: 3
# Training error 0.2506903155921394
# Testing error 0.24987401229902717
# [[ 2.79992766  1.90594975]
#  [-2.20107137  0.16025252]
#  [-3.80293866  1.63529723]] [[ 1.80377517]
#  [-0.69989499]
#  [-1.78554555]]
# epoch: 4
# Training error 0.250316543023061
# Testing error 0.25027604228368805
# [[ 2.68742246  1.71193743]
#  [-2.07642408  0.23964705]
#  [-3.85275579  1.75090395]] [[ 1.79952134]
#  [-0.82470389]
#  [-1.7284784 ]]
# epoch: 5
# Training error 0.25097821577796026
# Testing error 0.2515304374649691
# [[ 2.57470171  1.44607031]
#  [-1.92132096  0.37161798]
#  [-3.91317961  1.92486313]] [[ 1.76324087]
#  [-0.94420441]
#  [-1.6489739 ]]
# epoch: 6
# Training error 0.25310789592434607
# Testing error 0.2540863083092802
# [[ 2.48021914  1.12111637]
#  [-1.74387087  0.56260968]
#  [-4.00027857  2.14143123]] [[ 1.66243743]
#  [-1.04727535]
#  [-1.51186112]]
# epoch: 7
# Training error 0.2563090460673847
# Testing error 0.25767996067699894
# [[ 2.41616185  0.75677256]
#  [-1.55406565  0.81692417]
#  [-4.11623877  2.37803499]] [[ 1.44970449]
#  [-1.10879062]
#  [-1.26244368]]
# epoch: 8
# Training error 0.25801434993238603
# Testing error 0.260030297959988
# [[ 2.37481718  0.38969175]
#  [-1.35775913  1.13145474]
#  [-4.23379309  2.59444294]] [[ 1.07346268]
#  [-1.08234005]
#  [-0.83853734]]
# epoch: 9
# Training error 0.25372890432691086
# Testing error 0.2568202032476119
# [[ 2.33206157  0.09442369]
#  [-1.15728584  1.47311007]
#  [-4.30710703  2.71466369]] [[ 0.50975775]
#  [-0.91095803]
#  [-0.21852255]]
# epoch: 10
# Training error 0.24242331282598745
# Testing error 0.24652054356089662
# [[ 2.29353715 -0.01793576]
#  [-0.97257406  1.7524761 ]
#  [-4.34155512  2.64281279]] [[-0.20048482]
#  [-0.59534274]
#  [ 0.52191874]]
# epoch: 11
# Training error 0.2308469245483241
# Testing error 0.23502682363032681
# [[ 2.34316511  0.10250967]
#  [-0.85760304  1.88563244]
#  [-4.44877578  2.3716639 ]] [[-0.94992922]
#  [-0.25422641]
#  [ 1.24515413]]
# epoch: 12
# Training error 0.22499876042881956
# Testing error 0.22841550247063114
# [[ 2.57923986  0.35799899]
#  [-0.8534793   1.89875533]
#  [-4.74577329  2.03278034]] [[-1.62640652]
#  [-0.01876493]
#  [ 1.86629999]]
# epoch: 13
# Training error 0.22363906460338734
# Testing error 0.22616668362243694
# [[ 3.01299711  0.6140738 ]
#  [-0.93982991  1.86958963]
#  [-5.24400797  1.75524569]] [[-2.18434928]
#  [ 0.09818484]
#  [ 2.37867147]]
# epoch: 14
# Training error 0.22352930985690278
# Testing error 0.22538945400097138
# [[ 3.60713003  0.80930288]
#  [-1.07889923  1.8382937 ]
#  [-5.90446017  1.57991965]] [[-2.64169639]
#  [ 0.15634111]
#  [ 2.80691671]]
# epoch: 15
# Training error 0.22289505071099228
# Testing error 0.22433301729222013
# [[ 4.33884419  0.93503404]
#  [-1.25361789  1.81385965]
#  [-6.70304885  1.4996059 ]] [[-3.03438737]
#  [ 0.20104773]
#  [ 3.18124386]]
# epoch: 16
# Training error 0.22116130150362698
# Testing error 0.2223948093675727
# [[ 5.21121974  1.001263  ]
#  [-1.46314121  1.7963489 ]
#  [-7.64143004  1.49426301]] [[-3.39169515]
#  [ 0.24964557]
#  [ 3.52802934]]
# epoch: 17
# Training error 0.21837097507015535
# Testing error 0.2195761269222148
# [[ 6.24532823  1.02472027]
#  [-1.71297853  1.78414161]
#  [-8.73966529  1.54070931]] [[-3.73293478]
#  [ 0.3058444 ]
#  [ 3.86511608]]
# epoch: 18
# Training error 0.21484035353898265
# Testing error 0.21613418225600015
# [[  7.47024864   1.02293809]
#  [ -2.01029674   1.77534705]
#  [-10.0263804    1.61725316]] [[-4.06915841]
#  [ 0.36876412]
#  [ 4.20152261]]
# epoch: 19
# Training error 0.21093679052521272
# Testing error 0.21237473532332504
# [[  8.91506226   1.00993944]
#  [ -2.36198089   1.76826653]
#  [-11.53055287   1.70721978]] [[-4.40531998]
#  [ 0.436257  ]
#  [ 4.5398304 ]]
# epoch: 20
# Training error 0.20694829370640042
# Testing error 0.20853792513400865
# [[ 10.60435311   0.99443191]
#  [ -2.77378078   1.76168467]
#  [-13.27675201   1.80022103]] [[-4.74250864]
#  [ 0.50620523]
#  [ 4.87918745]]
# epoch: 21
# Training error 0.20304259722325918
# Testing error 0.2047627939484764
# [[ 12.5571361    0.98039818]
#  [ -3.25014715   1.75493311]
#  [-15.28390417   1.891195  ]] [[-5.07989377]
#  [ 0.57714165]
#  [ 5.21760355]]
# epoch: 22
# Training error 0.19928447892072623
# Testing error 0.20110033013033024
# [[ 14.78790887   0.96873548]
#  [ -3.79458824   1.7477682 ]
#  [-17.56629386   1.97852633]] [[-5.41606357]
#  [ 0.64847548]
#  [ 5.55315134]]
# epoch: 23
# Training error 0.1956670950511392
# Testing error 0.19753795597654755
# [[ 17.30852247   0.95867815]
#  [ -4.41035028   1.74020985]
#  [-20.13543754   2.06248655]] [[-5.74973391]
#  [ 0.72050383]
#  [ 5.88437699]]
# epoch: 24
# Training error 0.1921351063939737
# Testing error 0.19401772027976566
# [[ 20.13028674   0.94860852]
#  [ -5.10129195   1.73242851]
#  [-23.00219567   2.14435276]] [[-6.0800133 ]
#  [ 0.79437024]
#  [ 6.21033661]]
# epoch: 25
# Training error 0.18859898127964192
# Testing error 0.19044787715948935
# [[ 23.26616522   0.93643998]
#  [ -5.87290039   1.72468083]
#  [-26.17895838   2.22598495]] [[-6.406429  ]
#  [ 0.87203141]
#  [ 6.53049072]]
# epoch: 26
# Training error 0.1849453400598309
# Testing error 0.1867116581917698
# [[ 26.73290597   0.91982101]
#  [ -6.73341806   1.71726898]
#  [-29.6817424    2.30959146]] [[-6.72884393]
#  [ 0.95622982]
#  [ 6.84453894]]
# epoch: 27
# Training error 0.18104686930531386
# Testing error 0.18267609791754905
# [[ 30.55278298   0.89630013]
#  [ -7.6950389    1.71050633]
#  [-33.53186313   2.39753421]] [[-7.04732223]
#  [ 1.05045216]
#  [ 7.15221832]]
# epoch: 28
# Training error 0.17677491501888512
# Testing error 0.17820378941123827
# [[ 34.75440402   0.86352909]
#  [ -8.77508639   1.70467788]
#  [-37.75662269   2.49209236]] [[-7.36196133]
#  [ 1.158827  ]
#  [ 7.45307141]]
# epoch: 29
# Training error 0.17201860040829298
# Testing error 0.17317134809085497
# [[ 39.37173364   0.81957343]
#  [ -9.99695058   1.69998279]
#  [-42.38814881   2.59511368]] [[-7.67269595]
#  [ 1.28586389]
#  [ 7.7461933 ]]
# epoch: 30
# Training error 0.1667135487025496
# Testing error 0.16749794233132018
# [[ 44.44016995   0.76338605]
#  [-11.39028708   1.69644676]
#  [-47.45922546   2.7074983 ]] [[-7.97909356]
#  [ 1.43588994]
#  [ 8.02999199]]
# epoch: 31
# Training error 0.1608768855124497
# Testing error 0.16118146950665233
# [[ 49.98869007   0.69541033]
#  [-12.98963868   1.69380828]
#  [-52.9951861    2.82855638]] [[-8.28020436]
#  [ 1.61209036]
#  [ 8.3020477 ]]
# epoch: 32
# Training error 0.15462880771564588
# Testing error 0.15432386345705493
# [[ 56.02868698   0.61803284]
#  [-14.8306543    1.69142912]
#  [-59.00264394   2.95554005]] [[-8.57458373]
#  [ 1.81537863]
#  [ 8.55920938]]
# epoch: 33
# Training error 0.14816420373272132
# Testing error 0.1471121776312786
# [[ 62.54329524   0.53528658]
#  [-16.94417306   1.68833656]
#  [-65.45903162   3.08397692]] [[-8.86057663]
#  [ 2.04388439]
#  [ 8.79805601]]
# epoch: 34
# Training error 0.14165901518266186
# Testing error 0.13974604222645456
# [[ 69.48232975   0.45135482]
#  [-19.3501865    1.68349944]
#  [-72.30800573   3.20926916]] [[-9.13668955]
#  [ 2.29382297]
#  [ 9.01575891]]
# epoch: 35
# Training error 0.13516793638423052
# Testing error 0.13235594538040152
# [[ 76.76369486   0.36857998]
#  [-22.05352988   1.67630314]
#  [-79.46122523   3.32882888]] [[-9.40163758]
#  [ 2.56116308]
#  [ 9.21117728]]
# epoch: 36
# Training error 0.12860858547557233
# Testing error 0.1249703720727018
# [[ 84.2780835    0.28698771]
#  [-25.04104481   1.66683822]
#  [-86.8032802    3.44267767]] [[-9.65430887]
#  [ 2.84254765]
#  [ 9.38541689]]
# epoch: 37
# Training error 0.12185181039714199
# Testing error 0.11754956621930816
# [[ 91.89448757   0.20618767]
#  [-28.27925176   1.65549542]
#  [-94.19761737   3.55158956]] [[-9.89446412]
#  [ 3.1347771 ]
#  [ 9.54105923]]
# epoch: 38
# Training error 0.1148325988831489
# Testing error 0.11003664792082012
# [[  99.4638314     0.12733577]
#  [ -31.71155747    1.64232266]
#  [-101.4909564     3.65502849]] [[-10.12341149]
#  [  3.43280128]
#  [  9.68111094]]
# epoch: 39
# Training error 0.10763777860473564
# Testing error 0.1024354302687548
# [[ 1.06826263e+02  5.37211901e-02]
#  [-3.52576286e+01  1.62690537e+00]
#  [-1.08522279e+02  3.75037978e+00]] [[-10.34336835]
#  [  3.72782807]
#  [  9.80883171]]
# epoch: 40
# Training error 0.10049555296105914
# Testing error 0.09489388315662081
# [[ 1.13835329e+02 -1.01841949e-02]
#  [-3.88239236e+01  1.60874016e+00]
#  [-1.15149140e+02  3.83384248e+00]] [[-10.55612584]
#  [  4.00981466]
#  [  9.92784465]]
# epoch: 41
# Training error 0.09358742952946915
# Testing error 0.08759335015967051
# [[ 1.20383129e+02 -6.23205317e-02]
#  [-4.23216125e+01  1.58811564e+00]
#  [-1.21272633e+02  3.90387959e+00]] [[-10.76253867]
#  [  4.27303831]
#  [ 10.04220563]]
# epoch: 42
# Training error 0.08700501978524618
# Testing error 0.08066095638456827
# [[ 1.26395839e+02 -1.03561193e-01]
#  [-4.56732829e+01  1.56562446e+00]
#  [-1.26830400e+02  3.96146933e+00]] [[-10.96428399]
#  [  4.5157589 ]
#  [ 10.15530829]]
# epoch: 43
# Training error 0.08086559943693464
# Testing error 0.07418449615343606
# [[ 131.81637653   -0.13417156]
#  [ -48.81049438    1.5408736 ]
#  [-131.77760796    4.0067031 ]] [[-11.16464264]
#  [  4.73507038]
#  [ 10.26908527]]
# epoch: 44
# Training error 0.0754235747793239
# Testing error 0.0683753817350529
# [[ 136.61548609   -0.14846098]
#  [ -51.68359793    1.51042611]
#  [-136.0971365     4.03408554]] [[-11.36860469]
#  [  4.92647072]
#  [ 10.3826453 ]]
# epoch: 45
# Training error 0.07087989850078756
# Testing error 0.06351573938948826
# [[ 140.80119067   -0.14084858]
#  [ -54.27010032    1.47078691]
#  [-139.80748438    4.03844067]] [[-11.57899653]
#  [  5.08918338]
#  [ 10.49529023]]
# epoch: 46
# Training error 0.06715146038316842
# Testing error 0.05969250897291001
# [[ 1.44398197e+02 -1.15373733e-01]
#  [-5.65645853e+01  1.42340390e+00]
#  [-1.42941131e+02  4.02369578e+00]] [[-11.79334991]
#  [  5.22810827]
#  [ 10.61037464]]
# epoch: 47
# Training error 0.06405491960025665
# Testing error 0.05679251829100539
# [[ 1.47422953e+02 -7.98252189e-02]
#  [-5.85636579e+01  1.37181543e+00]
#  [-1.45520128e+02  3.99728473e+00]] [[-12.00893557]
#  [  5.34806051]
#  [ 10.73199215]]
# epoch: 48
# Training error 0.06155954731749551
# Testing error 0.05468721319726466
# [[ 1.49879795e+02 -3.66638113e-02]
#  [-6.02622844e+01  1.31704025e+00]
#  [-1.47553314e+02  3.96172828e+00]] [[-12.22690893]
#  [  5.44958831]
#  [ 10.86121894]]
# epoch: 49
# Training error 0.059691788467285664
# Testing error 0.0532541537930668
# [[ 1.51762983e+02  1.38750878e-02]
#  [-6.16543761e+01  1.25928655e+00]
#  [-1.49038940e+02  3.91745301e+00]] [[-12.44890949]
#  [  5.53164817]
#  [ 10.99855238]]
# epoch: 50
# Training error 0.05839308398897038
# Testing error 0.05233286510866381
# [[ 1.53056653e+02  6.94781855e-02]
#  [-6.27324828e+01  1.20019087e+00]
#  [-1.49964746e+02  3.86668753e+00]] [[-12.67464386]
#  [  5.5937226 ]
#  [ 11.14588805]]
# epoch: 51
# Training error 0.057599300737750596
# Testing error 0.05182557771507178
# [[ 1.53741886e+02  1.28215371e-01]
#  [-6.34915824e+01  1.14127949e+00]
#  [-1.50314702e+02  3.81125854e+00]] [[-12.90380938]
#  [  5.6353831 ]
#  [ 11.30458917]]
# epoch: 52
# Training error 0.0572941690010712
# Testing error 0.051739578888826306
# [[ 153.80262168    0.18967292]
#  [ -63.93237001    1.08315738]
#  [-150.07468654    3.75157781]] [[-13.13657895]
#  [  5.65672793]
#  [ 11.47468033]]
# epoch: 53
# Training error 0.05746551442751453
# Testing error 0.05211571570903652
# [[ 153.22816081    0.25366004]
#  [ -64.06215663    1.02605809]
#  [-149.23483201    3.68782891]] [[-13.3727157 ]
#  [  5.65962033]
#  [ 11.65546649]]
# epoch: 54
# Training error 0.05807170911703668
# Testing error 0.05296252367548389
# [[ 152.01091472    0.31942015]
#  [ -63.89245922    0.97016492]
#  [-147.78738694    3.62072953]] [[-13.61149425]
#  [  5.64781336]
#  [ 11.84587722]]
# epoch: 55
# Training error 0.05905417061825848
# Testing error 0.05424999105630585
# [[ 150.13821224    0.3858301 ]
#  [ -63.43357278    0.91552778]
#  [-145.71921809    3.55137303]] [[-13.85222496]
#  [  5.62574195]
#  [ 12.04448532]]
# epoch: 56
# Training error 0.06036966605125353
# Testing error 0.05593966843014486
# [[ 147.58370421    0.45186294]
#  [ -62.68985523    0.86196043]
#  [-143.00412397    3.48078514]] [[-14.09444077]
#  [  5.59733466]
#  [ 12.24960229]]
# epoch: 57
# Training error 0.061996792402522836
# Testing error 0.05799749237414939
# [[ 144.30407685    0.51660629]
#  [ -61.65841047    0.80919464]
#  [-139.60004556    3.40987455]] [[-14.33747506]
#  [  5.56574824]
#  [ 12.45958536]]
# epoch: 58
# Training error 0.06392037308457574
# Testing error 0.060384943544725844
# [[ 140.24306961    0.57912528]
#  [ -60.33124362    0.7570698 ]
#  [-135.45286118    3.33955885]] [[-14.58014508]
#  [  5.53359513]
#  [ 12.67292978]]
# epoch: 59
# Training error 0.0661161565495305
# Testing error 0.0630496385571538
# [[ 135.34026562    0.63847617]
#  [ -58.69895342    0.70559154]
#  [-130.50441542    3.27078562]] [[-14.82085629]
#  [  5.50315819]
#  [ 12.88807001]]
# epoch: 60
# Training error 0.06854014292491399
# Testing error 0.06592040495998884
# [[ 129.53966123    0.69374489]
#  [ -56.75359344    0.65492402]
#  [-124.70028071    3.20452538]] [[-15.0578213 ]
#  [  5.47654538]
#  [ 13.10324082]]
# epoch: 61
# Training error 0.07113033148315671
# Testing error 0.06890988388796068
# [[ 122.79426142    0.74412544]
#  [ -54.48950482    0.60531433]
#  [-117.99398075    3.14170477]] [[-15.28930522]
#  [  5.45571105]
#  [ 13.31644479]]
# epoch: 62
# Training error 0.07383295962186716
# Testing error 0.07193224513476366
# [[ 115.0658587     0.78919131]
#  [ -51.90232956    0.55690959]
#  [-110.34709685    3.08295681]] [[-15.51401499]
#  [  5.44223378]
#  [ 13.52531129]]
# epoch: 63
# Training error 0.07665378280111931
# Testing error 0.07494247363795818
# [[ 106.32107926    0.82939455]
#  [ -48.98698087    0.50948812]
#  [-101.72634434    3.02817554]] [[-15.73161031]
#  [  5.43690552]
#  [ 13.72675841]]
# epoch: 64
# Training error 0.07971906566688133
# Testing error 0.07800386417686965
# [[ 96.52465219   0.86662192]
#  [-45.73502065   0.46217484]
#  [-92.09842188   2.97600811]] [[-15.94301713]
#  [  5.43940735]
#  [ 13.91665998]]
# epoch: 65
# Training error 0.08329859137735374
# Testing error 0.081365890901391
# [[ 85.6302552    0.90412548]
#  [-42.13152929   0.41336232]
#  [-81.42266609   2.92383204]] [[-16.14973041]
#  [  5.44874733]
#  [ 14.09015116]]
# epoch: 66
# Training error 0.0877042111941143
# Testing error 0.08542731435737061
# [[ 73.57358203   0.94464252]
#  [-38.15302784   0.3613596 ]
#  [-69.64530133   2.86927775]] [[-16.3515895 ]
#  [  5.46471932]
#  [ 14.24306194]]
# epoch: 67
# Training error 0.09302945836595689
# Testing error 0.09037189371261103
# [[ 60.29066832   0.9866704 ]
#  [-33.77360185   0.30603511]
#  [-56.71482606   2.81342999]] [[-16.54457967]
#  [  5.48952936]
#  [ 14.37350176]]
# epoch: 68
# Training error 0.09922444846828728
# Testing error 0.09599189514635503
# [[ 45.75165288   1.02537369]
#  [-28.97324016   0.2484032 ]
#  [-42.60875401   2.76028092]] [[-16.7231335 ]
#  [  5.52785102]
#  [ 14.48008238]]
# epoch: 69
# Training error 0.10734901213806344
# Testing error 0.10332766462220122
# [[ 29.92695837   1.05588199]
#  [-23.7211509    0.18901462]
#  [-27.30040867   2.71418306]] [[-16.87819124]
#  [  5.58763393]
#  [ 14.56303759]]
# epoch: 70
# Training error 0.24702812752238834
# Testing error 0.2367301252433785
# [[ 19.22849084   0.36040969]
#  [-19.97364565   0.36162919]
#  [-16.90886631   3.30826141]] [[-16.80996517]
#  [  5.31641967]
#  [ 14.75748442]]
# epoch: 71
# Training error 0.2481837111535475
# Testing error 0.23790427505652165
# [[ 19.1713487    0.52465104]
#  [-19.98183401   0.22457709]
#  [-16.70070998   3.15997958]] [[-16.8112112 ]
#  [  5.41929562]
#  [ 14.75663565]]
# epoch: 72
# Training error 0.24764302225899945
# Testing error 0.2372723710477283
# [[ 19.2102052    0.40634183]
#  [-20.01996283   0.19877654]
#  [-16.61877151   3.26270743]] [[-16.84938001]
#  [  5.46789876]
#  [ 14.75499583]]
# epoch: 73
# Training error 0.2474127253952003
# Testing error 0.23699374503663123
# [[ 19.39883621   0.37912373]
#  [-20.11671302   0.14411576]
#  [-16.69104907   3.28493853]] [[-16.88863736]
#  [  5.54766665]
#  [ 14.73927554]]
# epoch: 74
# Training error 0.24713977339401744
# Testing error 0.23667476896632764
# [[ 19.59101274   0.34139401]
#  [-20.21463768   0.09864867]
#  [-16.77766813   3.3161837 ]] [[-16.92578346]
#  [  5.62718009]
#  [ 14.72348662]]
# epoch: 75
# Training error 0.24690265066979178
# Testing error 0.23639652559167115
# [[ 19.78229592   0.3083584 ]
#  [-20.31222964   0.05618081]
#  [-16.87223928   3.34313171]] [[-16.95890466]
#  [  5.70777887]
#  [ 14.70804761]]
# epoch: 76
# Training error 0.24670378742469104
# Testing error 0.23615869254686406
# [[ 1.99625794e+01  2.78325365e-01]
#  [-2.04053646e+01  1.69085508e-02]
#  [-1.69638190e+01  3.36730066e+00]] [[-16.98971586]
#  [  5.78532509]
#  [ 14.69261198]]
# epoch: 77
# Training error 0.2465341782096262
# Testing error 0.23595278520067875
# [[ 2.01307771e+01  2.49656834e-01]
#  [-2.04934525e+01 -1.90167500e-02]
#  [-1.70504474e+01  3.39017648e+00]] [[-17.01787809]
#  [  5.85958429]
#  [ 14.67790345]]
# epoch: 78
# Training error 0.24638979893548923
# Testing error 0.23577489016378325
# [[ 20.28758588   0.22260776]
#  [-20.57667196  -0.05212721]
#  [-17.13195735   3.41157432]] [[-17.04364399]
#  [  5.93041103]
#  [ 14.66397425]]
# epoch: 79
# Training error 0.24626643985167596
# Testing error 0.2356207466586738
# [[ 20.43375723   0.19711718]
#  [-20.65524716  -0.0827824 ]
#  [-17.20836509   3.43157475]] [[-17.06733312]
#  [  5.99772261]
#  [ 14.65079971]]
# epoch: 80
# Training error 0.2461602667008874
# Testing error 0.23548643546903447
# [[ 20.57018306   0.1730098 ]
#  [-20.72948195  -0.11125035]
#  [-17.27993095   3.45035107]] [[-17.08917566]
#  [  6.06161635]
#  [ 14.63837346]]
# epoch: 81
# Training error 0.24606822822351898
# Testing error 0.23536877316917731
# [[ 20.69777764   0.15016405]
#  [-20.79971067  -0.13777709]
#  [-17.34702175   3.46802452]] [[-17.10936739]
#  [  6.12226803]
#  [ 14.62667057]]
# epoch: 82
# Training error 0.24598791455710256
# Testing error 0.2352651816768983
# [[ 20.81738163   0.12848786]
#  [-20.8662538   -0.16258188]
#  [-17.4100051    3.48468652]] [[-17.12808687]
#  [  6.17987338]
#  [ 14.61564979]]
# epoch: 83
# Training error 0.2459173912108916
# Testing error 0.23517354142418892
# [[ 20.92974244   0.10789432]
#  [-20.9294053   -0.18585258]
#  [-17.46922013   3.50042086]] [[-17.1454926 ]
#  [  6.23463155]
#  [ 14.6052649 ]]
# epoch: 84
# Training error 0.2458550933903617
# Testing error 0.235092099381831
# [[ 21.03552154   0.08829947]
#  [-20.98943218  -0.20774943]
#  [-17.52497513   3.51530643]] [[-17.16172234]
#  [  6.28673853]
#  [ 14.59547014]]
# epoch: 85
# Training error 0.2457997509673977
# Testing error 0.2350194022449012
# [[ 21.13530447   0.06962516]
#  [-21.0465763   -0.22841027]
#  [-17.57754906   3.52941536]] [[-17.17689555]
#  [  6.33638231]
#  [ 14.58622176]]
# epoch: 86
# Training error 0.24575032843933142
# Testing error 0.23495424114330585
# [[ 21.22960984   0.05180022]
#  [-21.10105623  -0.24795467]
#  [-17.6271934    3.54281242]] [[-17.19111625]
#  [  6.38373977]
#  [ 14.57747851]]
# epoch: 87
# Training error 0.24570597651069256
# Testing error 0.2348956057894967
# [[ 21.31889733   0.03476025]
#  [-21.15306924  -0.26648685]
#  [-17.67413424   3.55555553]] [[-17.20447545]
#  [  6.42897523]
#  [ 14.5692019 ]]
# epoch: 88
# Training error 0.24566599393334468
# Testing error 0.2348426474371957
# [[ 2.14035752e+01  1.84468931e-02]
#  [-2.12027934e+01 -2.84097932e-01]
#  [-1.77185748e+01  3.56769665e+00]] [[-17.21705303]
#  [  6.47224016]
#  [ 14.56135636]]
# epoch: 89
# Training error 0.24562979782476482
# Testing error 0.23479464936417957
# [[ 2.14840069e+01  2.80719167e-03]
#  [-2.12503895e+01 -3.00867953e-01]
#  [-1.77606978e+01  3.57928254e+00]] [[-17.22891932]
#  [  6.51367361]
#  [ 14.55390918]]
# epoch: 90
# Training error 0.24559690059373215
# Testing error 0.23475100336272897
# [[ 2.15605172e+01 -1.22069711e-02]
#  [-2.12960033e+01 -3.16867429e-01]
#  [-1.78006682e+01  3.59035530e+00]] [[-17.24013637]
#  [  6.55340291]
#  [ 14.54683049]]
# epoch: 91
# Training error 0.2455668918959986
# Testing error 0.2347111909112341
# [[ 21.63339686  -0.02663933]
#  [-21.3397668   -0.33215875]
#  [-17.83863511   3.60095297]] [[-17.25075913]
#  [  6.5915445 ]
#  [ 14.54009302]]
# epoch: 92
# Training error 0.24553942441558463
# Testing error 0.23467476799320458
# [[ 21.70290723  -0.04052965]
#  [-21.38179997  -0.34679735]
#  [-17.87473347   3.61110988]] [[-17.26083642]
#  [  6.62820487]
#  [ 14.53367192]]
# epoch: 93
# Training error 0.24551420257895257
# Testing error 0.23464135278217105
# [[ 21.76928391  -0.05391416]
#  [-21.42221212  -0.36083263]
#  [-17.90908602   3.62085714]] [[-17.27041169]
#  [  6.66348135]
#  [ 14.52754455]]
# epoch: 94
# Training error 0.2454909735384315
# Testing error 0.23461061559839033
# [[ 21.83273982  -0.06682584]
#  [-21.46110302  -0.37430881]
#  [-17.94180449   3.63022295]] [[-17.2795238 ]
#  [  6.69746301]
#  [ 14.52169028]]
# epoch: 95
# Training error 0.24546951992531066
# Testing error 0.23458227067907525
# [[ 21.89346798  -0.07929482]
#  [-21.4985639   -0.3872656 ]
#  [-17.97299087   3.6392329 ]] [[-17.28820758]
#  [  6.7302314 ]
#  [ 14.51609031]]
# epoch: 96
# Training error 0.24544965399194524
# Testing error 0.23455606940416812
# [[ 21.95164384  -0.09134863]
#  [-21.53467841  -0.39973875]
#  [-18.0027385    3.64791029]] [[-17.29649435]
#  [  6.76186128]
#  [ 14.51072747]]
# epoch: 97
# Training error 0.24543121285026553
# Testing error 0.23453179469568752
# [[ 22.00742724  -0.10301248]
#  [-21.56952334  -0.41176057]
#  [-18.03113295   3.65627638]] [[-17.30441232]
#  [  6.79242124]
#  [ 14.50558607]]
# epoch: 98
# Training error 0.24541405458034599
# Testing error 0.23450925636735723
# [[ 22.06096422  -0.11430952]
#  [-21.60316937  -0.42336033]
#  [-18.05825283   3.66435057]] [[-17.31198701]
#  [  6.82197434]
#  [ 14.50065176]]
# epoch: 99
# Training error 0.24539805503307469
# Testing error 0.23448828724698045
# [[ 22.11238846  -0.12526098]
#  [-21.63568169  -0.43456463]
#  [-18.08417057   3.67215064]] [[-17.31924156]
#  [  6.8505786 ]
#  [ 14.4959114 ]]
# epoch: 100
# Training error 0.24538310518949247
# Testing error 0.234468739929877
# [[ 22.16182265  -0.13588642]
#  [-21.66712051  -0.4453977 ]
#  [-18.10895294   3.67969289]] [[-17.32619697]
#  [  6.87828751]
#  [ 14.49135293]]

# %%
# The follwoing is for XOR
# number of test cases

#initialisation of weight vectors
alpha=np.random.uniform(-4,4,6)
alpha=alpha.reshape(3,2)
beta=np.array([np.random.uniform(-4,4,3)]).T


# The follwoing is for AND
# number of test cases
T=5000
N=int(0.8*T)
M=int(0.2*T)

y=np.ones(T)

# each node in input layer is either 0 or 1 (with some noise)
x1=np.random.randint(0,2,T)
x2=np.random.randint(0,2,T)

#converting to float
x1=x1.astype(float)
x2=x2.astype(float)

#if both nodes are 1 then output node should be 1
for i in range(T):
    if x1[i]==0 and x2[i]==0:
        y[i]=0
    elif x1[i] and x2[i]:
        y[i]=0
        
#adding noise
x1 += np.random.normal(mean, std, T)
x2 += np.random.normal(mean, std, T)

# appending a row of ones, reshaping the matrix
X=np.array([np.ones(T),x1,x2])
X=X.reshape(3,T)


#plotting the input data points
plt.plot(X[1,:],X[2,:],'o',label='pts')
plt.legend()
plt.grid(1)
plt.xlabel('x1')
plt.ylabel('x2') 
plt.show()

#size of mini batch
m=50
#number of epochs
epoch =100
#learning rate
gamma=0.05

#The vector for mse values of training data
R_train=np.empty([1])
#The vector for mse values of testing data
R_test=np.empty([1])

# looping over epoch
for i in range(epoch):
    #looping over the mini batches
    for j in range(N//m):
        #z is sgm(alpha.T * X)
        z=np.matmul(alpha.T,X[:,j*m:(j+1)*m])
        z=z.reshape(1,2*m)
        for idx in range(2*m):
            z[0][idx]=sigmoid(z[0][idx]) 
        
        z=np.append(np.ones(m),z)
        z=z.reshape(3,m)     
        #y_cap is sigmoid of beta.T * z
        y_cap=np.matmul(beta.T,z)
        
        for idx in range(m):
            y_cap[0][idx]=sigmoid(y_cap[0][idx])
        #print(beta,y_cap)
        delta=-2*(y[j*m:(j+1)*m]-y_cap)
        
        #making the delta vector( 1 cross m)
        for idx in range(m):
                delta[0][idx]=delta[0][idx]*sigmoid_der(np.dot(beta.T,z[:,idx]))
        # making the S matrix (3 cross m)
        S=np.matmul(beta,delta)
        for idx in range(3):
            for itr in range(m):
                S[idx][itr]=S[idx][itr]*sigmoid(z[idx][itr])*(1-sigmoid(z[idx][itr]))
        
        #updating the weight vector
        beta-=gamma*np.matmul(z,delta.T)
        alpha-=gamma*np.matmul(S,X[1:,j*m:(j+1)*m].T)
        
    # finding z after every epoch        
    z=np.matmul(alpha.T,X)
    z=z.reshape(1,2*T)
    for idx in range(2*T):
        z[0][idx]=sigmoid(z[0][idx])
    
    z=np.append(np.ones(T),z)
    z=z.reshape(3,T)
    
    #finding the y cap after every epoch 
    y_cap=np.matmul(beta.T,z)   
    for idx in range(T):
        y_cap[0][idx]=sigmoid(y_cap[0][idx])
    
    # storing the errors in an array
    print("epoch:",i+1)
    R_train=np.append(R_train,np.sum((y[:N]-y_cap[0,:N])**2)/N)
    R_test=np.append(R_test,np.sum((y[N:T]-y_cap[0,N:T])**2)/M)
    print("Training error",np.sum((y[:N]-y_cap[0,:N])**2)/N)
    print("Testing error",np.sum((y[N:T]-y_cap[0,N:T])**2)/M)
    
#plotting the results
plt.plot(np.linspace(1,epoch,epoch),R_train[1:], 'r',label='training error')
plt.plot(np.linspace(1,epoch,epoch),R_test[1:],label='testing error')
plt.legend()
plt.grid()
plt.show()
# Out:
# epoch: 1
# Training error 0.21197174026641039
# Testing error 0.212688181838604
# epoch: 2
# Training error 0.18933665872806416
# Testing error 0.1914691315782464
# epoch: 3
# Training error 0.18468086478492557
# Testing error 0.18621857491496477
# epoch: 4
# Training error 0.1984827067144868
# Testing error 0.20054412273166375
# epoch: 5
# Training error 0.21717160025201157
# Testing error 0.21997431852848431
# epoch: 6
# Training error 0.23256659315268388
# Testing error 0.23588995617169184
# epoch: 7
# Training error 0.2437584005902147
# Testing error 0.2473352861792847
# epoch: 8
# Training error 0.25189170355034673
# Testing error 0.25551149296128917
# epoch: 9
# Training error 0.25719680288170116
# Testing error 0.26060654149430845
# epoch: 10
# Training error 0.26044163427876904
# Testing error 0.2634414181608902
# epoch: 11
# Training error 0.26236813375603923
# Testing error 0.26487105882048395
# epoch: 12
# Training error 0.26229386033452623
# Testing error 0.2642367991028403
# epoch: 13
# Training error 0.2588848630885707
# Testing error 0.2602139003266099
# epoch: 14
# Training error 0.25321992272238525
# Testing error 0.2539991114769941
# epoch: 15
# Training error 0.24934399782637864
# Testing error 0.24977730134487677
# epoch: 16
# Training error 0.2483265657570517
# Testing error 0.24859535679780004
# epoch: 17
# Training error 0.2486699332670474
# Testing error 0.24887763945412872
# epoch: 18
# Training error 0.2492933949961855
# Testing error 0.2494955304922457
# epoch: 19
# Training error 0.24979620612326436
# Testing error 0.25002358224435817
# epoch: 20
# Training error 0.2500947161248914
# Testing error 0.2503642396322521
# epoch: 21
# Training error 0.2502182210564876
# Testing error 0.25053809620964707
# epoch: 22
# Training error 0.25022498919357267
# Testing error 0.2505976385722317
# epoch: 23
# Training error 0.25016997241082173
# Testing error 0.25059394058996487
# epoch: 24
# Training error 0.25009411081535865
# Testing error 0.25056542695135353
# epoch: 25
# Training error 0.2500230256845649
# Testing error 0.25053621765003714
# epoch: 26
# Training error 0.24996959362042986
# Testing error 0.2505184455229815
# epoch: 27
# Training error 0.24993766541986007
# Testing error 0.2505157735831025
# epoch: 28
# Training error 0.24992559065318687
# Testing error 0.2505267581575783
# epoch: 29
# Training error 0.24992899872013646
# Testing error 0.25054750075513843
# epoch: 30
# Training error 0.24994272314825294
# Testing error 0.25057347001166663
# epoch: 31
# Training error 0.24996196728132986
# Testing error 0.25060058756787734
# epoch: 32
# Training error 0.24998288663430906
# Testing error 0.25062574965064555
# epoch: 33
# Training error 0.2500027692454009
# Testing error 0.25064696280504
# epoch: 34
# Training error 0.2500199696340999
# Testing error 0.25066324693553177
# epoch: 35
# Training error 0.2500337159595889
# Testing error 0.25067442304828774
# epoch: 36
# Training error 0.2500438741240984
# Testing error 0.2506808673545427
# epoch: 37
# Training error 0.25005072147586693
# Testing error 0.2506832823762121
# epoch: 38
# Training error 0.2500547581861541
# Testing error 0.2506825112119892
# epoch: 39
# Training error 0.25005656662088044
# Testing error 0.2506794035328563
# epoch: 40
# Training error 0.25005671756759557
# Testing error 0.2506747306529233
# epoch: 41
# Training error 0.25005571593819265
# Testing error 0.25066914106860616
# epoch: 42
# Training error 0.2500539762007544
# Testing error 0.25066314579625726
# epoch: 43
# Training error 0.2500518179439895
# Testing error 0.25065712327665624
# epoch: 44
# Training error 0.2500494734831921
# Testing error 0.2506513353689782
# epoch: 45
# Training error 0.25004710141825387
# Testing error 0.25064594815572755
# epoch: 46
# Training error 0.2500448020086283
# Testing error 0.25064105337853687
# epoch: 47
# Training error 0.2500426318591924
# Testing error 0.2506366880497877
