# %%
#importing librarier
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
#defining sigmoid function and its derivative
def sigmoid (x):
    return 1/(1+np.exp(-x))

def sigmoid_der (x):
    return sigmoid(x)*(1-sigmoid(x))

#mean , standard deviation for noise
mean=0
std=0.03

# %%
# The follwoing is for XOR
# number of test cases

#initialisation of weight vectors
#alpha=np.random.uniform(-4,4,6)
#alpha=alpha.reshape(3,2)
#beta=np.array([np.random.uniform(-4,4,3)]).T
#print(alpha,beta)
alpha=np.array([[-7,-7],[7,7],[7,7]]).astype(float)
beta=np.array([[-],[14],[-7]]).astype(float)
# The follwoing is for AND
# number of test cases
T=1000
N=int(0.8*T)
M=int(0.2*T)

y=np.ones(T)

# each node in input layer is either 0 or 1 (with some noise)
x1=np.random.randint(0,2,T)
x2=np.random.randint(0,2,T)

#converting to float
x1=x1.astype(float)
x2=x2.astype(float)

#if both nodes are 1 then output node should be 1
for i in range(T):
    if x1[i]==0 and x2[i]==0:
        y[i]=0
    elif x1[i] and x2[i]:
        y[i]=0
        
#adding noise
x1 += np.random.normal(mean, std, T)
x2 += np.random.normal(mean, std, T)

# appending a row of ones, reshaping the matrix
X=np.array([np.ones(T),x1,x2])
X=X.reshape(3,T)


#plotting the input data points
plt.plot(X[1,:],X[2,:],'o',label='pts')
plt.legend()
plt.grid(1)
plt.xlabel('x1')
plt.ylabel('x2') 
plt.show()

#size of mini batch
m=50
#number of epochs
epoch =100
#learning rate
gamma=0.05

#The vector for mse values of training data
R_train=np.empty([1])
#The vector for mse values of testing data
R_test=np.empty([1])

# looping over epoch
for i in range(epoch):
    #looping over the mini batches
    for j in range(N//m):
        #z is sgm(alpha.T * X)
        z=np.matmul(alpha.T,X[:,j*m:(j+1)*m])
        z=z.reshape(1,2*m)
        for idx in range(2*m):
            z[0][idx]=sigmoid(z[0][idx]) 
        
        z=np.append(np.ones(m),z)
        z=z.reshape(3,m)     
        #y_cap is sigmoid of beta.T * z
        y_cap=np.matmul(beta.T,z)
        
        for idx in range(m):
            y_cap[0][idx]=sigmoid(y_cap[0][idx])
        #print(beta,y_cap)
        delta=-2*(y[j*m:(j+1)*m]-y_cap)
        
        #making the delta vector( 1 cross m)
        for idx in range(m):
                delta[0][idx]=delta[0][idx]*sigmoid_der(np.dot(beta.T,z[:,idx]))
        # making the S matrix (3 cross m)
        S=np.matmul(beta,delta)
        for idx in range(3):
            for itr in range(m):
                S[idx][itr]=S[idx][itr]*sigmoid(z[idx][itr])*(1-sigmoid(z[idx][itr]))
        
        #updating the weight vector
        beta-=gamma*np.matmul(z,delta.T)
        alpha-=gamma*np.matmul(S,X[1:,j*m:(j+1)*m].T)
        
    # finding z after every epoch        
    z=np.matmul(alpha.T,X)
    z=z.reshape(1,2*T)
    for idx in range(2*T):
        z[0][idx]=sigmoid(z[0][idx])
    
    z=np.append(np.ones(T),z)
    z=z.reshape(3,T)
    
    #finding the y cap after every epoch 
    y_cap=np.matmul(beta.T,z)   
    for idx in range(T):
        y_cap[0][idx]=sigmoid(y_cap[0][idx])
    
    # storing the errors in an array
    print("epoch:",i+1)
    R_train=np.append(R_train,np.sum((y[:N]-y_cap[0,:N])**2)/N)
    R_test=np.append(R_test,np.sum((y[N:T]-y_cap[0,N:T])**2)/M)
    print("Training error",np.sum((y[:N]-y_cap[0,:N])**2)/N)
    print("Testing error",np.sum((y[N:T]-y_cap[0,N:T])**2)/M)
    print(alpha,beta)
#print("Observation: Saddle point is reached")    
#plotting the results
plt.plot(np.linspace(1,epoch,epoch),R_train[1:], 'r',label='training error')
plt.plot(np.linspace(1,epoch,epoch),R_test[1:],label='testing error')
plt.legend()
plt.grid()
plt.show()
# Out:
# epoch: 1
# Training error 0.5224361332744077
# Testing error 0.4799355411929654
# [[-6.00449436 -6.00001425]
#  [-6.9911092  -5.99997182]
#  [ 2.99555459  8.9999882 ]] [[-8.99744949]
#  [14.00000034]
#  [-6.99999363]]
# epoch: 2
# Training error 0.5224359707725383
# Testing error 0.479935377063788
# [[-6.00899893 -6.00002847]
#  [-6.98219567 -5.99994371]
#  [ 2.99109783  8.99997642]] [[-8.99489249]
#  [14.00000067]
#  [-6.99998729]]
# epoch: 3
# Training error 0.5224358074276562
# Testing error 0.4799352120843271
# [[-6.01351375 -6.00004265]
#  [-6.97325931 -5.99991566]
#  [ 2.98662965  8.99996466]] [[-8.99232899]
#  [14.00000099]
#  [-6.99998096]]
# epoch: 4
# Training error 0.5224356432334024
# Testing error 0.4799350462481577
# [[-6.01803888 -6.00005679]
#  [-6.96429998 -5.99988768]
#  [ 2.98214999  8.99995294]] [[-8.98975894]
#  [14.00000132]
#  [-6.99997466]]
# epoch: 5
# Training error 0.52243547818335
# Testing error 0.47993487954878616
# [[-6.02257437 -6.00007089]
#  [-6.95531758 -5.99985976]
#  [ 2.9776588   8.99994123]] [[-8.98718231]
#  [14.00000164]
#  [-6.99996837]]
# epoch: 6
# Training error 0.5224353122710041
# Testing error 0.4799347119796501
# [[-6.02712027 -6.00008496]
#  [-6.94631198 -5.9998319 ]
#  [ 2.97315602  8.99992955]] [[-8.98459906]
#  [14.00000195]
#  [-6.99996211]]
# epoch: 7
# Training error 0.5224351454897999
# Testing error 0.47993454353411685
# [[-6.03167662 -6.000099  ]
#  [-6.93728307 -5.9998041 ]
#  [ 2.96864158  8.99991789]] [[-8.98200916]
#  [14.00000227]
#  [-6.99995586]]
# epoch: 8
# Training error 0.5224349778331026
# Testing error 0.4799343742054832
# [[-6.03624348 -6.000113  ]
#  [-6.92823073 -5.99977636]
#  [ 2.96411543  8.99990626]] [[-8.97941259]
#  [14.00000258]
#  [-6.99994964]]
# epoch: 9
# Training error 0.5224348092942059
# Testing error 0.47993420398697384
# [[-6.0408209  -6.00012697]
#  [-6.91915482 -5.99974869]
#  [ 2.95957751  8.99989465]] [[-8.97680929]
#  [14.00000288]
#  [-6.99994343]]
# epoch: 10
# Training error 0.5224346398663324
# Testing error 0.479934032871741
# [[-6.04540893 -6.0001409 ]
#  [-6.91005524 -5.99972106]
#  [ 2.95502775  8.99988306]] [[-8.97419924]
#  [14.00000318]
#  [-6.99993724]]
# epoch: 11
# Training error 0.5224344695426306
# Testing error 0.4799338608528636
# [[-6.05000762 -6.0001548 ]
#  [-6.90093186 -5.9996935 ]
#  [ 2.9504661   8.99987149]] [[-8.9715824 ]
#  [14.00000348]
#  [-6.99993107]]
# epoch: 12
# Training error 0.5224342983161762
# Testing error 0.4799336879233456
# [[-6.05461703 -6.00016867]
#  [-6.89178455 -5.99966598]
#  [ 2.94589248  8.99985994]] [[-8.96895873]
#  [14.00000378]
#  [-6.99992492]]
# epoch: 13
# Training error 0.5224341261799693
# Testing error 0.479933514076116
# [[-6.0592372  -6.00018251]
#  [-6.88261318 -5.99963852]
#  [ 2.94130685  8.99984842]] [[-8.9663282 ]
#  [14.00000407]
#  [-6.99991879]]
# epoch: 14
# Training error 0.5224339531269347
# Testing error 0.47993333930402704
# [[-6.0638682  -6.00019632]
#  [-6.87341764 -5.99961112]
#  [ 2.93670912  8.99983691]] [[-8.96369077]
#  [14.00000435]
#  [-6.99991267]]
# epoch: 15
# Training error 0.5224337791499206
# Testing error 0.47993316359985383
# [[-6.06851006 -6.0002101 ]
#  [-6.86419779 -5.99958376]
#  [ 2.93209925  8.99982542]] [[-8.96104641]
#  [14.00000464]
#  [-6.99990657]]
# epoch: 16
# Training error 0.5224336042416973
# Testing error 0.47993298695629294
# [[-6.07316286 -6.00022385]
#  [-6.8549535  -5.99955646]
#  [ 2.92747717  8.99981395]] [[-8.95839507]
#  [14.00000492]
#  [-6.99990049]]
# epoch: 17
# Training error 0.5224334283949563
# Testing error 0.4799328093659617
# [[-6.07782663 -6.00023757]
#  [-6.84568465 -5.9995292 ]
#  [ 2.92284281  8.9998025 ]] [[-8.95573672]
#  [14.0000052 ]
#  [-6.99989442]]
# epoch: 18
# Training error 0.5224332516023097
# Testing error 0.479932630821397
# [[-6.08250144 -6.00025126]
#  [-6.83639111 -5.99950199]
#  [ 2.9181961   8.99979107]] [[-8.95307133]
#  [14.00000547]
#  [-6.99988837]]
# epoch: 19
# Training error 0.5224330738562887
# Testing error 0.4799324513150542
# [[-6.08718734 -6.00026493]
#  [-6.82707274 -5.99947483]
#  [ 2.91353699  8.99977965]] [[-8.95039885]
#  [14.00000574]
#  [-6.99988234]]
# epoch: 20
# Training error 0.5224328951493427
# Testing error 0.4799322708393063
# [[-6.09188439 -6.00027857]
#  [-6.81772941 -5.99944771]
#  [ 2.9088654   8.99976825]] [[-8.94771925]
#  [14.00000601]
#  [-6.99987632]]
# epoch: 21
# Training error 0.5224327154738382
# Testing error 0.4799320893864426
# [[-6.09659264 -6.00029218]
#  [-6.80836098 -5.99942064]
#  [ 2.90418127  8.99975687]] [[-8.94503248]
#  [14.00000628]
#  [-6.99987032]]
# epoch: 22
# Training error 0.5224325348220578
# Testing error 0.47993190694866766
# [[-6.10131215 -6.00030576]
#  [-6.79896733 -5.99939361]
#  [ 2.89948453  8.99974551]] [[-8.94233852]
#  [14.00000654]
#  [-6.99986433]]
# epoch: 23
# Training error 0.5224323531861993
# Testing error 0.47993172351810054
# [[-6.10604298 -6.00031932]
#  [-6.78954832 -5.99936662]
#  [ 2.89477511  8.99973416]] [[-8.93963731]
#  [14.0000068 ]
#  [-6.99985836]]
# epoch: 24
# Training error 0.5224321705583741
# Testing error 0.479931539086773
# [[-6.11078518 -6.00033286]
#  [-6.7801038  -5.99933967]
#  [ 2.89005295  8.99972283]] [[-8.93692883]
#  [14.00000706]
#  [-6.9998524 ]]
# epoch: 25
# Training error 0.5224319869306061
# Testing error 0.4799313536466289
# [[-6.1155388  -6.00034637]
#  [-6.77063365 -5.99931277]
#  [ 2.88531797  8.99971151]] [[-8.93421302]
#  [14.00000731]
#  [-6.99984646]]
# epoch: 26
# Training error 0.5224318022948311
# Testing error 0.47993116718952294
# [[-6.12030392 -6.00035986]
#  [-6.76113772 -5.9992859 ]
#  [ 2.88057011  8.9997002 ]] [[-8.93148986]
#  [14.00000756]
#  [-6.99984053]]
# epoch: 27
# Training error 0.5224316166428951
# Testing error 0.47993097970721904
# [[-6.12508059 -6.00037332]
#  [-6.75161587 -5.99925907]
#  [ 2.87580929  8.99968891]] [[-8.92875929]
#  [14.00000781]
#  [-6.99983461]]
# epoch: 28
# Training error 0.5224314299665531
# Testing error 0.4799307911913898
# [[-6.12986886 -6.00038677]
#  [-6.74206796 -5.99923228]
#  [ 2.87103545  8.99967763]] [[-8.92602128]
#  [14.00000806]
#  [-6.99982871]]
# epoch: 29
# Training error 0.5224312422574682
# Testing error 0.47993060163361484
# [[-6.1346688  -6.00040019]
#  [-6.73249385 -5.99920552]
#  [ 2.86624851  8.99966637]] [[-8.9232758 ]
#  [14.0000083 ]
#  [-6.99982282]]
# epoch: 30
# Training error 0.5224310535072102
# Testing error 0.4799304110253793
# [[-6.13948046 -6.00041358]
#  [-6.72289339 -5.9991788 ]
#  [ 2.8614484   8.99965512]] [[-8.92052279]
#  [14.00000854]
#  [-6.99981694]]
# epoch: 31
# Training error 0.5224308637072543
# Testing error 0.4799302193580735
# [[-6.14430391 -6.00042696]
#  [-6.71326645 -5.99915211]
#  [ 2.85663506  8.99964388]] [[-8.91776221]
#  [14.00000877]
#  [-6.99981108]]
# epoch: 32
# Training error 0.5224306728489797
# Testing error 0.4799300266229906
# [[-6.14913921 -6.00044032]
#  [-6.70361286 -5.99912545]
#  [ 2.85180839  8.99963265]] [[-8.91499403]
#  [14.00000901]
#  [-6.99980523]]
# epoch: 33
# Training error 0.5224304809236685
# Testing error 0.4799298328113257
# [[-6.15398641 -6.00045365]
#  [-6.69393249 -5.99909883]
#  [ 2.84696834  8.99962144]] [[-8.91221819]
#  [14.00000924]
#  [-6.99979939]]
# epoch: 34
# Training error 0.5224302879225046
# Testing error 0.4799296379141748
# [[-6.15884559 -6.00046697]
#  [-6.68422519 -5.99907223]
#  [ 2.84211483  8.99961023]] [[-8.90943467]
#  [14.00000947]
#  [-6.99979356]]
# epoch: 35
# Training error 0.5224300938365716
# Testing error 0.47992944192253306
# [[-6.1637168  -6.00048027]
#  [-6.6744908  -5.99904567]
#  [ 2.83724778  8.99959904]] [[-8.90664341]
#  [14.0000097 ]
#  [-6.99978774]]
# epoch: 36
# Training error 0.5224298986568519
# Testing error 0.47992924482729327
# [[-6.1686001  -6.00049355]
#  [-6.66472918 -5.99901913]
#  [ 2.83236712  8.99958786]] [[-8.90384437]
#  [14.00000992]
#  [-6.99978194]]
# epoch: 37
# Training error 0.5224297023742258
# Testing error 0.47992904661924496
# [[-6.17349557 -6.00050681]
#  [-6.65494017 -5.99899262]
#  [ 2.82747277  8.99957668]] [[-8.9010375 ]
#  [14.00001014]
#  [-6.99977615]]
# epoch: 38
# Training error 0.5224295049794692
# Testing error 0.4799288472890727
# [[-6.17840325 -6.00052005]
#  [-6.64512362 -5.99896614]
#  [ 2.82256465  8.99956552]] [[-8.89822277]
#  [14.00001036]
#  [-6.99977036]]
# epoch: 39
# Training error 0.5224293064632525
# Testing error 0.4799286468273546
# [[-6.18332323 -6.00053328]
#  [-6.63527937 -5.99893968]
#  [ 2.81764269  8.99955436]] [[-8.89540013]
#  [14.00001058]
#  [-6.99976459]]
# epoch: 40
# Training error 0.5224291068161391
# Testing error 0.4799284452245604
# [[-6.18825556 -6.00054649]
#  [-6.62540727 -5.99891325]
#  [ 2.81270681  8.99954322]] [[-8.89256953]
#  [14.00001079]
#  [-6.99975883]]
# epoch: 41
# Training error 0.5224289060285842
# Testing error 0.4799282424710512
# [[-6.1932003  -6.00055968]
#  [-6.61550716 -5.99888684]
#  [ 2.80775692  8.99953208]] [[-8.88973093]
#  [14.00001101]
#  [-6.99975308]]
# epoch: 42
# Training error 0.5224287040909327
# Testing error 0.47992803855707633
# [[-6.19815753 -6.00057286]
#  [-6.60557888 -5.99886046]
#  [ 2.80279296  8.99952095]] [[-8.88688428]
#  [14.00001122]
#  [-6.99974733]]
# epoch: 43
# Training error 0.5224285009934184
# Testing error 0.4799278334727734
# [[-6.20312732 -6.00058602]
#  [-6.59562228 -5.99883409]
#  [ 2.79781484  8.99950982]] [[-8.88402954]
#  [14.00001142]
#  [-6.9997416 ]]
# epoch: 44
# Training error 0.5224282967261619
# Testing error 0.47992762720816523
# [[-6.20810971 -6.00059917]
#  [-6.58563718 -5.99880775]
#  [ 2.79282248  8.99949871]] [[-8.88116665]
#  [14.00001163]
#  [-6.99973588]]
# epoch: 45
# Training error 0.5224280912791684
# Testing error 0.4799274197531592
# [[-6.2131048  -6.00061231]
#  [-6.57562342 -5.99878143]
#  [ 2.78781579  8.9994876 ]] [[-8.87829558]
#  [14.00001183]
#  [-6.99973017]]
# epoch: 46
# Training error 0.5224278846423279
# Testing error 0.47992721109754527
# [[-6.21811264 -6.00062543]
#  [-6.56558085 -5.99875512]
#  [ 2.7827947   8.9994765 ]] [[-8.87541627]
#  [14.00001203]
#  [-6.99972446]]
# epoch: 47
# Training error 0.5224276768054118
# Testing error 0.47992700123099424
# [[-6.2231333  -6.00063854]
#  [-6.55550929 -5.99872884]
#  [ 2.77775912  8.9994654 ]] [[-8.87252868]
#  [14.00001223]
#  [-6.99971876]]
# epoch: 48
# Training error 0.5224274677580716
# Testing error 0.4799267901430565
# [[-6.22816685 -6.00065163]
#  [-6.54540858 -5.99870257]
#  [ 2.77270897  8.99945431]] [[-8.86963276]
#  [14.00001243]
#  [-6.99971308]]
# epoch: 49
# Training error 0.522427257489838
# Testing error 0.47992657782315945
# [[-6.23321336 -6.00066471]
#  [-6.53527855 -5.99867632]
#  [ 2.76764417  8.99944322]] [[-8.86672846]
#  [14.00001262]
#  [-6.9997074 ]]
# epoch: 50
# Training error 0.5224270459901181
# Testing error 0.4799263642606064
# [[-6.23827291 -6.00067778]
#  [-6.52511903 -5.99865008]
#  [ 2.76256462  8.99943214]] [[-8.86381573]
#  [14.00001282]
#  [-6.99970172]]
# epoch: 51
# Training error 0.5224268332481945
# Testing error 0.4799261494445748
# [[-6.24334556 -6.00069084]
#  [-6.51492984 -5.99862386]
#  [ 2.75747025  8.99942106]] [[-8.86089453]
#  [14.00001301]
#  [-6.99969606]]
# epoch: 52
# Training error 0.5224266192532226
# Testing error 0.47992593336411404
# [[-6.24843139 -6.00070389]
#  [-6.50471081 -5.99859765]
#  [ 2.75236096  8.99940999]] [[-8.85796479]
#  [14.0000132 ]
#  [-6.9996904 ]]
# epoch: 53
# Training error 0.5224264039942296
# Testing error 0.4799257160081437
# [[-6.25353046 -6.00071692]
#  [-6.49446178 -5.99857145]
#  [ 2.74723667  8.99939892]] [[-8.85502648]
#  [14.00001338]
#  [-6.99968475]]
# epoch: 54
# Training error 0.5224261874601117
# Testing error 0.47992549736545187
# [[-6.25864285 -6.00072995]
#  [-6.48418255 -5.99854526]
#  [ 2.74209729  8.99938785]] [[-8.85207954]
#  [14.00001357]
#  [-6.99967911]]
# epoch: 55
# Training error 0.5224259696396336
# Testing error 0.4799252774246929
# [[-6.26376864 -6.00074297]
#  [-6.47387296 -5.99851909]
#  [ 2.73694274  8.99937679]] [[-8.84912392]
#  [14.00001375]
#  [-6.99967348]]
# epoch: 56
# Training error 0.522425750521425
# Testing error 0.4799250561743857
# [[-6.26890789 -6.00075598]
#  [-6.46353282 -5.99849292]
#  [ 2.73177291  8.99936573]] [[-8.84615957]
#  [14.00001393]
#  [-6.99966785]]
# epoch: 57
# Training error 0.5224255300939796
# Testing error 0.4799248336029116
# [[-6.27406069 -6.00076898]
#  [-6.45316195 -5.99846677]
#  [ 2.72658773  8.99935467]] [[-8.84318643]
#  [14.00001411]
#  [-6.99966222]]
# epoch: 58
# Training error 0.5224253083456527
# Testing error 0.4799246096985125
# [[-6.27922711 -6.00078197]
#  [-6.44276018 -5.99844062]
#  [ 2.7213871   8.99934361]] [[-8.84020446]
#  [14.00001429]
#  [-6.99965661]]
# epoch: 59
# Training error 0.5224250852646593
# Testing error 0.47992438444928837
# [[-6.28440722 -6.00079495]
#  [-6.4323273  -5.99841448]
#  [ 2.71617092  8.99933256]] [[-8.8372136 ]
#  [14.00001446]
#  [-6.999651  ]]
# epoch: 60
# Training error 0.5224248608390718
# Testing error 0.4799241578431958
# [[-6.2896011  -6.00080792]
#  [-6.42186315 -5.99838834]
#  [ 2.71093911  8.9993215 ]] [[-8.8342138 ]
#  [14.00001464]
#  [-6.99964539]]
# epoch: 61
# Training error 0.5224246350568184
# Testing error 0.47992392986804516
# [[-6.29480883 -6.00082089]
#  [-6.41136753 -5.99836221]
#  [ 2.70569157  8.99931045]] [[-8.831205  ]
#  [14.00001481]
#  [-6.99963979]]
# epoch: 62
# Training error 0.5224244079056802
# Testing error 0.4799237005114989
# [[-6.30003048 -6.00083385]
#  [-6.40084025 -5.99833609]
#  [ 2.7004282   8.9992994 ]] [[-8.82818715]
#  [14.00001498]
#  [-6.9996342 ]]
# epoch: 63
# Training error 0.5224241793732896
# Testing error 0.47992346976106903
# [[-6.30526614 -6.00084681]
#  [-6.39028112 -5.99830996]
#  [ 2.69514892  8.99928834]] [[-8.82516019]
#  [14.00001514]
#  [-6.99962861]]
# epoch: 64
# Training error 0.5224239494471276
# Testing error 0.47992323760411504
# [[-6.31051589 -6.00085976]
#  [-6.37968995 -5.99828385]
#  [ 2.68985362  8.99927729]] [[-8.82212407]
#  [14.00001531]
#  [-6.99962302]]
# epoch: 65
# Training error 0.522423718114522
# Testing error 0.47992300402784166
# [[-6.3157798  -6.0008727 ]
#  [-6.36906654 -5.99825773]
#  [ 2.68454221  8.99926624]] [[-8.81907874]
#  [14.00001548]
#  [-6.99961744]]
# epoch: 66
# Training error 0.5224234853626446
# Testing error 0.47992276901929626
# [[-6.32105795 -6.00088564]
#  [-6.35841069 -5.99823161]
#  [ 2.67921458  8.99925518]] [[-8.81602413]
#  [14.00001564]
#  [-6.99961187]]
# epoch: 67
# Training error 0.522423251178509
# Testing error 0.47992253256536654
# [[-6.32635044 -6.00089858]
#  [-6.34772222 -5.9982055 ]
#  [ 2.67387064  8.99924412]] [[-8.81296019]
#  [14.0000158 ]
#  [-6.9996063 ]]
# epoch: 68
# Training error 0.5224230155489683
# Testing error 0.4799222946527783
# [[-6.33165733 -6.00091151]
#  [-6.33700091 -5.99817938]
#  [ 2.6685103   8.99923306]] [[-8.80988686]
#  [14.00001596]
#  [-6.99960073]]
# epoch: 69
# Training error 0.5224227784607126
# Testing error 0.4799220552680925
# [[-6.33697871 -6.00092443]
#  [-6.32624656 -5.99815326]
#  [ 2.66313344  8.999222  ]] [[-8.80680409]
#  [14.00001612]
#  [-6.99959517]]
# epoch: 70
# Training error 0.5224225399002664
# Testing error 0.47992181439770326
# [[-6.34231467 -6.00093735]
#  [-6.31545898 -5.99812714]
#  [ 2.65773996  8.99921094]] [[-8.80371181]
#  [14.00001627]
#  [-6.99958961]]
# epoch: 71
# Training error 0.5224222998539861
# Testing error 0.479921572027835
# [[-6.34766529 -6.00095027]
#  [-6.30463796 -5.99810102]
#  [ 2.65232978  8.99919987]] [[-8.80060997]
#  [14.00001643]
#  [-6.99958405]]
# epoch: 72
# Training error 0.5224220583080572
# Testing error 0.4799213281445396
# [[-6.35303066 -6.00096319]
#  [-6.29378328 -5.99807489]
#  [ 2.64690277  8.9991888 ]] [[-8.7974985 ]
#  [14.00001658]
#  [-6.9995785 ]]
# epoch: 73
# Training error 0.5224218152484922
# Testing error 0.4799210827336944
# [[-6.35841086 -6.00097611]
#  [-6.28289474 -5.99804875]
#  [ 2.64145883  8.99917773]] [[-8.79437736]
#  [14.00001673]
#  [-6.99957294]]
# epoch: 74
# Training error 0.5224215706611272
# Testing error 0.47992083578099853
# [[-6.36380597 -6.00098902]
#  [-6.27197213 -5.99802261]
#  [ 2.63599786  8.99916666]] [[-8.79124646]
#  [14.00001688]
#  [-6.9995674 ]]
# epoch: 75
# Training error 0.5224213245316196
# Testing error 0.4799205872719711
# [[-6.36921609 -6.00100193]
#  [-6.26101523 -5.99799647]
#  [ 2.63051976  8.99915557]] [[-8.78810576]
#  [14.00001703]
#  [-6.99956185]]
# epoch: 76
# Training error 0.5224210768454453
# Testing error 0.4799203371919477
# [[-6.37464131 -6.00101485]
#  [-6.25002383 -5.99797032]
#  [ 2.62502441  8.99914449]] [[-8.7849552 ]
#  [14.00001718]
#  [-6.99955631]]
# epoch: 77
# Training error 0.5224208275878955
# Testing error 0.47992008552607784
# [[-6.3800817  -6.00102776]
#  [-6.23899771 -5.99794415]
#  [ 2.61951171  8.9991334 ]] [[-8.7817947 ]
#  [14.00001733]
#  [-6.99955077]]
# epoch: 78
# Training error 0.5224205767440744
# Testing error 0.4799198322593216
# [[-6.38553737 -6.00104067]
#  [-6.22793665 -5.99791798]
#  [ 2.61398154  8.9991223 ]] [[-8.77862421]
#  [14.00001747]
#  [-6.99954523]]
# epoch: 79
# Training error 0.5224203242988952
# Testing error 0.4799195773764473
# [[-6.39100841 -6.00105358]
#  [-6.21684043 -5.9978918 ]
#  [ 2.60843379  8.9991112 ]] [[-8.77544366]
#  [14.00001761]
#  [-6.99953969]]
# epoch: 80
# Training error 0.5224200702370783
# Testing error 0.47991932086202793
# [[-6.3964949  -6.00106649]
#  [-6.20570882 -5.99786561]
#  [ 2.60286836  8.99910009]] [[-8.772253  ]
#  [14.00001776]
#  [-6.99953415]]
# epoch: 81
# Training error 0.5224198145431473
# Testing error 0.4799190627004382
# [[-6.40199693 -6.0010794 ]
#  [-6.1945416  -5.9978394 ]
#  [ 2.59728513  8.99908898]] [[-8.76905214]
#  [14.0000179 ]
#  [-6.99952862]]
# epoch: 82
# Training error 0.5224195572014265
# Testing error 0.4799188028758512
# [[-6.40751461 -6.00109232]
#  [-6.18333854 -5.99781319]
#  [ 2.59168399  8.99907786]] [[-8.76584104]
#  [14.00001803]
#  [-6.99952308]]
# epoch: 83
# Training error 0.5224192981960372
# Testing error 0.47991854137223555
# [[-6.41304802 -6.00110523]
#  [-6.17209941 -5.99778696]
#  [ 2.58606481  8.99906673]] [[-8.76261962]
#  [14.00001817]
#  [-6.99951755]]
# epoch: 84
# Training error 0.5224190375108944
# Testing error 0.47991827817335164
# [[-6.41859727 -6.00111815]
#  [-6.16082398 -5.99776071]
#  [ 2.58042749  8.9990556 ]] [[-8.75938781]
#  [14.00001831]
#  [-6.99951202]]
# epoch: 85
# Training error 0.5224187751297039
# Testing error 0.47991801326274874
# [[-6.42416243 -6.00113107]
#  [-6.14951201 -5.99773445]
#  [ 2.57477191  8.99904445]] [[-8.75614555]
#  [14.00001844]
#  [-6.99950649]]
# epoch: 86
# Training error 0.5224185110359589
# Testing error 0.47991774662376124
# [[-6.42974362 -6.001144  ]
#  [-6.13816326 -5.99770818]
#  [ 2.56909795  8.9990333 ]] [[-8.75289277]
#  [14.00001858]
#  [-6.99950096]]
# epoch: 87
# Training error 0.5224182452129361
# Testing error 0.4799174782395052
# [[-6.43534093 -6.00115693]
#  [-6.1267775  -5.99768189]
#  [ 2.56340548  8.99902214]] [[-8.74962941]
#  [14.00001871]
#  [-6.99949542]]
# epoch: 88
# Training error 0.5224179776436924
# Testing error 0.4799172080928747
# [[-6.44095446 -6.00116986]
#  [-6.11535449 -5.99765558]
#  [ 2.55769439  8.99901098]] [[-8.74635538]
#  [14.00001884]
#  [-6.99948989]]
# epoch: 89
# Training error 0.522417708311061
# Testing error 0.4799169361665387
# [[-6.4465843  -6.00118279]
#  [-6.10389397 -5.99762925]
#  [ 2.55196456  8.9989998 ]] [[-8.74307063]
#  [14.00001897]
#  [-6.99948436]]
# epoch: 90
# Training error 0.522417437197649
# Testing error 0.4799166624429365
# [[-6.45223057 -6.00119573]
#  [-6.0923957  -5.9976029 ]
#  [ 2.54621586  8.99898861]] [[-8.73977508]
#  [14.0000191 ]
#  [-6.99947883]]
# epoch: 91
# Training error 0.5224171642858315
# Testing error 0.479916386904275
# [[-6.45789335 -6.00120868]
#  [-6.08085944 -5.99757653]
#  [ 2.54044816  8.99897742]] [[-8.73646866]
#  [14.00001923]
#  [-6.99947329]]
# epoch: 92
# Training error 0.5224168895577497
# Testing error 0.4799161095325238
# [[-6.46357276 -6.00122163]
#  [-6.06928493 -5.99755014]
#  [ 2.53466135  8.99896621]] [[-8.73315129]
#  [14.00001935]
#  [-6.99946776]]
# epoch: 93
# Training error 0.5224166129953062
# Testing error 0.4799158303094117
# [[-6.46926889 -6.00123459]
#  [-6.05767191 -5.99752373]
#  [ 2.52885529  8.99895499]] [[-8.72982291]
#  [14.00001948]
#  [-6.99946222]]
# epoch: 94
# Training error 0.5224163345801608
# Testing error 0.4799155492164232
# [[-6.47498185 -6.00124755]
#  [-6.04602014 -5.9974973 ]
#  [ 2.52302986  8.99894376]] [[-8.72648344]
#  [14.0000196 ]
#  [-6.99945668]]
# epoch: 95
# Training error 0.522416054293727
# Testing error 0.4799152662347936
# [[-6.48071174 -6.00126052]
#  [-6.03432934 -5.99747084]
#  [ 2.51718493  8.99893253]] [[-8.72313281]
#  [14.00001973]
#  [-6.99945115]]
# epoch: 96
# Training error 0.5224157721171675
# Testing error 0.47991498134550525
# [[-6.48645868 -6.00127349]
#  [-6.02259927 -5.99744436]
#  [ 2.51132036  8.99892128]] [[-8.71977094]
#  [14.00001985]
#  [-6.99944561]]
# epoch: 97
# Training error 0.5224154880313902
# Testing error 0.479914694529283
# [[-6.49222276 -6.00128648]
#  [-6.01082965 -5.99741785]
#  [ 2.50543603  8.99891001]] [[-8.71639775]
#  [14.00001997]
#  [-6.99944006]]
# epoch: 98
# Training error 0.5224152020170435
# Testing error 0.47991440576659045
# [[-6.4980041  -6.00129947]
#  [-5.99902022 -5.99739132]
#  [ 2.49953179  8.99889874]] [[-8.71301318]
#  [14.00002009]
#  [-6.99943452]]
# epoch: 99
# Training error 0.5224149140545125
# Testing error 0.47991411503762466
# [[-6.50380281 -6.00131247]
#  [-5.9871707  -5.99736476]
#  [ 2.49360752  8.99888745]] [[-8.70961713]
#  [14.00002021]
#  [-6.99942897]]
# epoch: 100
# Training error 0.522414624123914
# Testing error 0.4799138223223126
# [[-6.50961899 -6.00132548]
#  [-5.97528083 -5.99733818]
#  [ 2.48766308  8.99887615]] [[-8.70620954]
#  [14.00002032]
#  [-6.99942342]]

# %%
# The follwoing is for XOR
# number of test cases

#initialisation of weight vectors
alpha=np.random.uniform(-4,4,6)
alpha=alpha.reshape(3,2)
beta=np.array([np.random.uniform(-4,4,3)]).T


# The follwoing is for AND
# number of test cases
T=2500
N=int(0.8*T)
M=int(0.2*T)

y=np.ones(T)

# each node in input layer is either 0 or 1 (with some noise)
x1=np.random.randint(0,2,T)
x2=np.random.randint(0,2,T)

#converting to float
x1=x1.astype(float)
x2=x2.astype(float)

#if both nodes are 1 then output node should be 1
for i in range(T):
    if x1[i]==0 and x2[i]==0:
        y[i]=0
    elif x1[i] and x2[i]:
        y[i]=0
        
#adding noise
x1 += np.random.normal(mean, std, T)
x2 += np.random.normal(mean, std, T)

# appending a row of ones, reshaping the matrix
X=np.array([np.ones(T),x1,x2])
X=X.reshape(3,T)


#plotting the input data points
plt.plot(X[1,:],X[2,:],'o',label='pts')
plt.legend()
plt.grid(1)
plt.xlabel('x1')
plt.ylabel('x2') 
plt.show()

#size of mini batch
m=50
#number of epochs
epoch =100
#learning rate
gamma=0.05

#The vector for mse values of training data
R_train=np.empty([1])
#The vector for mse values of testing data
R_test=np.empty([1])

# looping over epoch
for i in range(epoch):
    #looping over the mini batches
    for j in range(N//m):
        #z is sgm(alpha.T * X)
        z=np.matmul(alpha.T,X[:,j*m:(j+1)*m])
        z=z.reshape(1,2*m)
        for idx in range(2*m):
            z[0][idx]=sigmoid(z[0][idx]) 
        
        z=np.append(np.ones(m),z)
        z=z.reshape(3,m)     
        #y_cap is sigmoid of beta.T * z
        y_cap=np.matmul(beta.T,z)
        
        for idx in range(m):
            y_cap[0][idx]=sigmoid(y_cap[0][idx])
        #print(beta,y_cap)
        delta=-2*(y[j*m:(j+1)*m]-y_cap)
        
        #making the delta vector( 1 cross m)
        for idx in range(m):
                delta[0][idx]=delta[0][idx]*sigmoid_der(np.dot(beta.T,z[:,idx]))
        # making the S matrix (3 cross m)
        S=np.matmul(beta,delta)
        for idx in range(3):
            for itr in range(m):
                S[idx][itr]=S[idx][itr]*sigmoid(z[idx][itr])*(1-sigmoid(z[idx][itr]))
        
        #updating the weight vector
        beta-=gamma*np.matmul(z,delta.T)
        alpha-=gamma*np.matmul(S,X[1:,j*m:(j+1)*m].T)
        
    # finding z after every epoch        
    z=np.matmul(alpha.T,X)
    z=z.reshape(1,2*T)
    for idx in range(2*T):
        z[0][idx]=sigmoid(z[0][idx])
    
    z=np.append(np.ones(T),z)
    z=z.reshape(3,T)
    
    #finding the y cap after every epoch 
    y_cap=np.matmul(beta.T,z)   
    for idx in range(T):
        y_cap[0][idx]=sigmoid(y_cap[0][idx])
    
    # storing the errors in an array
    print("epoch:",i+1)
    R_train=np.append(R_train,np.sum((y[:N]-y_cap[0,:N])**2)/N)
    R_test=np.append(R_test,np.sum((y[N:T]-y_cap[0,N:T])**2)/M)
    print("Training error",np.sum((y[:N]-y_cap[0,:N])**2)/N)
    print("Testing error",np.sum((y[N:T]-y_cap[0,N:T])**2)/M)
    print(alpha,beta)
#plotting the results
plt.plot(np.linspace(1,epoch,epoch),R_train[1:], 'r',label='training error')
plt.plot(np.linspace(1,epoch,epoch),R_test[1:],label='testing error')
plt.legend()
plt.grid()
plt.show()
# Out:
# epoch: 1
# Training error 0.253277567657006
# Testing error 0.2499008500137495
# [[ 2.95083013  2.01214938]
#  [-2.33943887  0.13359261]
#  [-3.64689348  1.66206205]] [[ 1.7701135 ]
#  [-0.38873012]
#  [-1.93191401]]
# epoch: 2
# Training error 0.25166614884052924
# Testing error 0.24985699898401117
# [[ 2.89506401  2.01595524]
#  [-2.29066595  0.12637577]
#  [-3.74406901  1.59386923]] [[ 1.79389093]
#  [-0.56791366]
#  [-1.84300217]]
# epoch: 3
# Training error 0.2506903155921394
# Testing error 0.24987401229902717
# [[ 2.79992766  1.90594975]
#  [-2.20107137  0.16025252]
#  [-3.80293866  1.63529723]] [[ 1.80377517]
#  [-0.69989499]
#  [-1.78554555]]
# epoch: 4
# Training error 0.250316543023061
# Testing error 0.25027604228368805
# [[ 2.68742246  1.71193743]
#  [-2.07642408  0.23964705]
#  [-3.85275579  1.75090395]] [[ 1.79952134]
#  [-0.82470389]
#  [-1.7284784 ]]
# epoch: 5
# Training error 0.25097821577796026
# Testing error 0.2515304374649691
# [[ 2.57470171  1.44607031]
#  [-1.92132096  0.37161798]
#  [-3.91317961  1.92486313]] [[ 1.76324087]
#  [-0.94420441]
#  [-1.6489739 ]]
# epoch: 6
# Training error 0.25310789592434607
# Testing error 0.2540863083092802
# [[ 2.48021914  1.12111637]
#  [-1.74387087  0.56260968]
#  [-4.00027857  2.14143123]] [[ 1.66243743]
#  [-1.04727535]
#  [-1.51186112]]
# epoch: 7
# Training error 0.2563090460673847
# Testing error 0.25767996067699894
# [[ 2.41616185  0.75677256]
#  [-1.55406565  0.81692417]
#  [-4.11623877  2.37803499]] [[ 1.44970449]
#  [-1.10879062]
#  [-1.26244368]]
# epoch: 8
# Training error 0.25801434993238603
# Testing error 0.260030297959988
# [[ 2.37481718  0.38969175]
#  [-1.35775913  1.13145474]
#  [-4.23379309  2.59444294]] [[ 1.07346268]
#  [-1.08234005]
#  [-0.83853734]]
# epoch: 9
# Training error 0.25372890432691086
# Testing error 0.2568202032476119
# [[ 2.33206157  0.09442369]
#  [-1.15728584  1.47311007]
#  [-4.30710703  2.71466369]] [[ 0.50975775]
#  [-0.91095803]
#  [-0.21852255]]
# epoch: 10
# Training error 0.24242331282598745
# Testing error 0.24652054356089662
# [[ 2.29353715 -0.01793576]
#  [-0.97257406  1.7524761 ]
#  [-4.34155512  2.64281279]] [[-0.20048482]
#  [-0.59534274]
#  [ 0.52191874]]
# epoch: 11
# Training error 0.2308469245483241
# Testing error 0.23502682363032681
# [[ 2.34316511  0.10250967]
#  [-0.85760304  1.88563244]
#  [-4.44877578  2.3716639 ]] [[-0.94992922]
#  [-0.25422641]
#  [ 1.24515413]]
# epoch: 12
# Training error 0.22499876042881956
# Testing error 0.22841550247063114
# [[ 2.57923986  0.35799899]
#  [-0.8534793   1.89875533]
#  [-4.74577329  2.03278034]] [[-1.62640652]
#  [-0.01876493]
#  [ 1.86629999]]
# epoch: 13
# Training error 0.22363906460338734
# Testing error 0.22616668362243694
# [[ 3.01299711  0.6140738 ]
#  [-0.93982991  1.86958963]
#  [-5.24400797  1.75524569]] [[-2.18434928]
#  [ 0.09818484]
#  [ 2.37867147]]
# epoch: 14
# Training error 0.22352930985690278
# Testing error 0.22538945400097138
# [[ 3.60713003  0.80930288]
#  [-1.07889923  1.8382937 ]
#  [-5.90446017  1.57991965]] [[-2.64169639]
#  [ 0.15634111]
#  [ 2.80691671]]
# epoch: 15
# Training error 0.22289505071099228
# Testing error 0.22433301729222013
# [[ 4.33884419  0.93503404]
#  [-1.25361789  1.81385965]
#  [-6.70304885  1.4996059 ]] [[-3.03438737]
#  [ 0.20104773]
#  [ 3.18124386]]
# epoch: 16
# Training error 0.22116130150362698
# Testing error 0.2223948093675727
# [[ 5.21121974  1.001263  ]
#  [-1.46314121  1.7963489 ]
#  [-7.64143004  1.49426301]] [[-3.39169515]
#  [ 0.24964557]
#  [ 3.52802934]]
# epoch: 17
# Training error 0.21837097507015535
# Testing error 0.2195761269222148
# [[ 6.24532823  1.02472027]
#  [-1.71297853  1.78414161]
#  [-8.73966529  1.54070931]] [[-3.73293478]
#  [ 0.3058444 ]
#  [ 3.86511608]]
# epoch: 18
# Training error 0.21484035353898265
# Testing error 0.21613418225600015
# [[  7.47024864   1.02293809]
#  [ -2.01029674   1.77534705]
#  [-10.0263804    1.61725316]] [[-4.06915841]
#  [ 0.36876412]
#  [ 4.20152261]]
# epoch: 19
# Training error 0.21093679052521272
# Testing error 0.21237473532332504
# [[  8.91506226   1.00993944]
#  [ -2.36198089   1.76826653]
#  [-11.53055287   1.70721978]] [[-4.40531998]
#  [ 0.436257  ]
#  [ 4.5398304 ]]
# epoch: 20
# Training error 0.20694829370640042
# Testing error 0.20853792513400865
# [[ 10.60435311   0.99443191]
#  [ -2.77378078   1.76168467]
#  [-13.27675201   1.80022103]] [[-4.74250864]
#  [ 0.50620523]
#  [ 4.87918745]]
# epoch: 21
# Training error 0.20304259722325918
# Testing error 0.2047627939484764
# [[ 12.5571361    0.98039818]
#  [ -3.25014715   1.75493311]
#  [-15.28390417   1.891195  ]] [[-5.07989377]
#  [ 0.57714165]
#  [ 5.21760355]]
# epoch: 22
# Training error 0.19928447892072623
# Testing error 0.20110033013033024
# [[ 14.78790887   0.96873548]
#  [ -3.79458824   1.7477682 ]
#  [-17.56629386   1.97852633]] [[-5.41606357]
#  [ 0.64847548]
#  [ 5.55315134]]
# epoch: 23
# Training error 0.1956670950511392
# Testing error 0.19753795597654755
# [[ 17.30852247   0.95867815]
#  [ -4.41035028   1.74020985]
#  [-20.13543754   2.06248655]] [[-5.74973391]
#  [ 0.72050383]
#  [ 5.88437699]]
# epoch: 24
# Training error 0.1921351063939737
# Testing error 0.19401772027976566
# [[ 20.13028674   0.94860852]
#  [ -5.10129195   1.73242851]
#  [-23.00219567   2.14435276]] [[-6.0800133 ]
#  [ 0.79437024]
#  [ 6.21033661]]
# epoch: 25
# Training error 0.18859898127964192
# Testing error 0.19044787715948935
# [[ 23.26616522   0.93643998]
#  [ -5.87290039   1.72468083]
#  [-26.17895838   2.22598495]] [[-6.406429  ]
#  [ 0.87203141]
#  [ 6.53049072]]
# epoch: 26
# Training error 0.1849453400598309
# Testing error 0.1867116581917698
# [[ 26.73290597   0.91982101]
#  [ -6.73341806   1.71726898]
#  [-29.6817424    2.30959146]] [[-6.72884393]
#  [ 0.95622982]
#  [ 6.84453894]]
# epoch: 27
# Training error 0.18104686930531386
# Testing error 0.18267609791754905
# [[ 30.55278298   0.89630013]
#  [ -7.6950389    1.71050633]
#  [-33.53186313   2.39753421]] [[-7.04732223]
#  [ 1.05045216]
#  [ 7.15221832]]
# epoch: 28
# Training error 0.17677491501888512
# Testing error 0.17820378941123827
# [[ 34.75440402   0.86352909]
#  [ -8.77508639   1.70467788]
#  [-37.75662269   2.49209236]] [[-7.36196133]
#  [ 1.158827  ]
#  [ 7.45307141]]
# epoch: 29
# Training error 0.17201860040829298
# Testing error 0.17317134809085497
# [[ 39.37173364   0.81957343]
#  [ -9.99695058   1.69998279]
#  [-42.38814881   2.59511368]] [[-7.67269595]
#  [ 1.28586389]
#  [ 7.7461933 ]]
# epoch: 30
# Training error 0.1667135487025496
# Testing error 0.16749794233132018
# [[ 44.44016995   0.76338605]
#  [-11.39028708   1.69644676]
#  [-47.45922546   2.7074983 ]] [[-7.97909356]
#  [ 1.43588994]
#  [ 8.02999199]]
# epoch: 31
# Training error 0.1608768855124497
# Testing error 0.16118146950665233
# [[ 49.98869007   0.69541033]
#  [-12.98963868   1.69380828]
#  [-52.9951861    2.82855638]] [[-8.28020436]
#  [ 1.61209036]
#  [ 8.3020477 ]]
# epoch: 32
# Training error 0.15462880771564588
# Testing error 0.15432386345705493
# [[ 56.02868698   0.61803284]
#  [-14.8306543    1.69142912]
#  [-59.00264394   2.95554005]] [[-8.57458373]
#  [ 1.81537863]
#  [ 8.55920938]]
# epoch: 33
# Training error 0.14816420373272132
# Testing error 0.1471121776312786
# [[ 62.54329524   0.53528658]
#  [-16.94417306   1.68833656]
#  [-65.45903162   3.08397692]] [[-8.86057663]
#  [ 2.04388439]
#  [ 8.79805601]]
# epoch: 34
# Training error 0.14165901518266186
# Testing error 0.13974604222645456
# [[ 69.48232975   0.45135482]
#  [-19.3501865    1.68349944]
#  [-72.30800573   3.20926916]] [[-9.13668955]
#  [ 2.29382297]
#  [ 9.01575891]]
# epoch: 35
# Training error 0.13516793638423052
# Testing error 0.13235594538040152
# [[ 76.76369486   0.36857998]
#  [-22.05352988   1.67630314]
#  [-79.46122523   3.32882888]] [[-9.40163758]
#  [ 2.56116308]
#  [ 9.21117728]]
# epoch: 36
# Training error 0.12860858547557233
# Testing error 0.1249703720727018
# [[ 84.2780835    0.28698771]
#  [-25.04104481   1.66683822]
#  [-86.8032802    3.44267767]] [[-9.65430887]
#  [ 2.84254765]
#  [ 9.38541689]]
# epoch: 37
# Training error 0.12185181039714199
# Testing error 0.11754956621930816
# [[ 91.89448757   0.20618767]
#  [-28.27925176   1.65549542]
#  [-94.19761737   3.55158956]] [[-9.89446412]
#  [ 3.1347771 ]
#  [ 9.54105923]]
# epoch: 38
# Training error 0.1148325988831489
# Testing error 0.11003664792082012
# [[  99.4638314     0.12733577]
#  [ -31.71155747    1.64232266]
#  [-101.4909564     3.65502849]] [[-10.12341149]
#  [  3.43280128]
#  [  9.68111094]]
# epoch: 39
# Training error 0.10763777860473564
# Testing error 0.1024354302687548
# [[ 1.06826263e+02  5.37211901e-02]
#  [-3.52576286e+01  1.62690537e+00]
#  [-1.08522279e+02  3.75037978e+00]] [[-10.34336835]
#  [  3.72782807]
#  [  9.80883171]]
# epoch: 40
# Training error 0.10049555296105914
# Testing error 0.09489388315662081
# [[ 1.13835329e+02 -1.01841949e-02]
#  [-3.88239236e+01  1.60874016e+00]
#  [-1.15149140e+02  3.83384248e+00]] [[-10.55612584]
#  [  4.00981466]
#  [  9.92784465]]
# epoch: 41
# Training error 0.09358742952946915
# Testing error 0.08759335015967051
# [[ 1.20383129e+02 -6.23205317e-02]
#  [-4.23216125e+01  1.58811564e+00]
#  [-1.21272633e+02  3.90387959e+00]] [[-10.76253867]
#  [  4.27303831]
#  [ 10.04220563]]
# epoch: 42
# Training error 0.08700501978524618
# Testing error 0.08066095638456827
# [[ 1.26395839e+02 -1.03561193e-01]
#  [-4.56732829e+01  1.56562446e+00]
#  [-1.26830400e+02  3.96146933e+00]] [[-10.96428399]
#  [  4.5157589 ]
#  [ 10.15530829]]
# epoch: 43
# Training error 0.08086559943693464
# Testing error 0.07418449615343606
# [[ 131.81637653   -0.13417156]
#  [ -48.81049438    1.5408736 ]
#  [-131.77760796    4.0067031 ]] [[-11.16464264]
#  [  4.73507038]
#  [ 10.26908527]]
# epoch: 44
# Training error 0.0754235747793239
# Testing error 0.0683753817350529
# [[ 136.61548609   -0.14846098]
#  [ -51.68359793    1.51042611]
#  [-136.0971365     4.03408554]] [[-11.36860469]
#  [  4.92647072]
#  [ 10.3826453 ]]
# epoch: 45
# Training error 0.07087989850078756
# Testing error 0.06351573938948826
# [[ 140.80119067   -0.14084858]
#  [ -54.27010032    1.47078691]
#  [-139.80748438    4.03844067]] [[-11.57899653]
#  [  5.08918338]
#  [ 10.49529023]]
# epoch: 46
# Training error 0.06715146038316842
# Testing error 0.05969250897291001
# [[ 1.44398197e+02 -1.15373733e-01]
#  [-5.65645853e+01  1.42340390e+00]
#  [-1.42941131e+02  4.02369578e+00]] [[-11.79334991]
#  [  5.22810827]
#  [ 10.61037464]]
# epoch: 47
# Training error 0.06405491960025665
# Testing error 0.05679251829100539
# [[ 1.47422953e+02 -7.98252189e-02]
#  [-5.85636579e+01  1.37181543e+00]
#  [-1.45520128e+02  3.99728473e+00]] [[-12.00893557]
#  [  5.34806051]
#  [ 10.73199215]]
# epoch: 48
# Training error 0.06155954731749551
# Testing error 0.05468721319726466
# [[ 1.49879795e+02 -3.66638113e-02]
#  [-6.02622844e+01  1.31704025e+00]
#  [-1.47553314e+02  3.96172828e+00]] [[-12.22690893]
#  [  5.44958831]
#  [ 10.86121894]]
# epoch: 49
# Training error 0.059691788467285664
# Testing error 0.0532541537930668
# [[ 1.51762983e+02  1.38750878e-02]
#  [-6.16543761e+01  1.25928655e+00]
#  [-1.49038940e+02  3.91745301e+00]] [[-12.44890949]
#  [  5.53164817]
#  [ 10.99855238]]
# epoch: 50
# Training error 0.05839308398897038
# Testing error 0.05233286510866381
# [[ 1.53056653e+02  6.94781855e-02]
#  [-6.27324828e+01  1.20019087e+00]
#  [-1.49964746e+02  3.86668753e+00]] [[-12.67464386]
#  [  5.5937226 ]
#  [ 11.14588805]]
# epoch: 51
# Training error 0.057599300737750596
# Testing error 0.05182557771507178
# [[ 1.53741886e+02  1.28215371e-01]
#  [-6.34915824e+01  1.14127949e+00]
#  [-1.50314702e+02  3.81125854e+00]] [[-12.90380938]
#  [  5.6353831 ]
#  [ 11.30458917]]
# epoch: 52
# Training error 0.0572941690010712
# Testing error 0.051739578888826306
# [[ 153.80262168    0.18967292]
#  [ -63.93237001    1.08315738]
#  [-150.07468654    3.75157781]] [[-13.13657895]
#  [  5.65672793]
#  [ 11.47468033]]
# epoch: 53
# Training error 0.05746551442751453
# Testing error 0.05211571570903652
# [[ 153.22816081    0.25366004]
#  [ -64.06215663    1.02605809]
#  [-149.23483201    3.68782891]] [[-13.3727157 ]
#  [  5.65962033]
#  [ 11.65546649]]
# epoch: 54
# Training error 0.05807170911703668
# Testing error 0.05296252367548389
# [[ 152.01091472    0.31942015]
#  [ -63.89245922    0.97016492]
#  [-147.78738694    3.62072953]] [[-13.61149425]
#  [  5.64781336]
#  [ 11.84587722]]
# epoch: 55
# Training error 0.05905417061825848
# Testing error 0.05424999105630585
# [[ 150.13821224    0.3858301 ]
#  [ -63.43357278    0.91552778]
#  [-145.71921809    3.55137303]] [[-13.85222496]
#  [  5.62574195]
#  [ 12.04448532]]
# epoch: 56
# Training error 0.06036966605125353
# Testing error 0.05593966843014486
# [[ 147.58370421    0.45186294]
#  [ -62.68985523    0.86196043]
#  [-143.00412397    3.48078514]] [[-14.09444077]
#  [  5.59733466]
#  [ 12.24960229]]
# epoch: 57
# Training error 0.061996792402522836
# Testing error 0.05799749237414939
# [[ 144.30407685    0.51660629]
#  [ -61.65841047    0.80919464]
#  [-139.60004556    3.40987455]] [[-14.33747506]
#  [  5.56574824]
#  [ 12.45958536]]
# epoch: 58
# Training error 0.06392037308457574
# Testing error 0.060384943544725844
# [[ 140.24306961    0.57912528]
#  [ -60.33124362    0.7570698 ]
#  [-135.45286118    3.33955885]] [[-14.58014508]
#  [  5.53359513]
#  [ 12.67292978]]
# epoch: 59
# Training error 0.0661161565495305
# Testing error 0.0630496385571538
# [[ 135.34026562    0.63847617]
#  [ -58.69895342    0.70559154]
#  [-130.50441542    3.27078562]] [[-14.82085629]
#  [  5.50315819]
#  [ 12.88807001]]
# epoch: 60
# Training error 0.06854014292491399
# Testing error 0.06592040495998884
# [[ 129.53966123    0.69374489]
#  [ -56.75359344    0.65492402]
#  [-124.70028071    3.20452538]] [[-15.0578213 ]
#  [  5.47654538]
#  [ 13.10324082]]
# epoch: 61
# Training error 0.07113033148315671
# Testing error 0.06890988388796068
# [[ 122.79426142    0.74412544]
#  [ -54.48950482    0.60531433]
#  [-117.99398075    3.14170477]] [[-15.28930522]
#  [  5.45571105]
#  [ 13.31644479]]
# epoch: 62
# Training error 0.07383295962186716
# Testing error 0.07193224513476366
# [[ 115.0658587     0.78919131]
#  [ -51.90232956    0.55690959]
#  [-110.34709685    3.08295681]] [[-15.51401499]
#  [  5.44223378]
#  [ 13.52531129]]
# epoch: 63
# Training error 0.07665378280111931
# Testing error 0.07494247363795818
# [[ 106.32107926    0.82939455]
#  [ -48.98698087    0.50948812]
#  [-101.72634434    3.02817554]] [[-15.73161031]
#  [  5.43690552]
#  [ 13.72675841]]
# epoch: 64
# Training error 0.07971906566688133
# Testing error 0.07800386417686965
# [[ 96.52465219   0.86662192]
#  [-45.73502065   0.46217484]
#  [-92.09842188   2.97600811]] [[-15.94301713]
#  [  5.43940735]
#  [ 13.91665998]]
# epoch: 65
# Training error 0.08329859137735374
# Testing error 0.081365890901391
# [[ 85.6302552    0.90412548]
#  [-42.13152929   0.41336232]
#  [-81.42266609   2.92383204]] [[-16.14973041]
#  [  5.44874733]
#  [ 14.09015116]]
# epoch: 66
# Training error 0.0877042111941143
# Testing error 0.08542731435737061
# [[ 73.57358203   0.94464252]
#  [-38.15302784   0.3613596 ]
#  [-69.64530133   2.86927775]] [[-16.3515895 ]
#  [  5.46471932]
#  [ 14.24306194]]
# epoch: 67
# Training error 0.09302945836595689
# Testing error 0.09037189371261103
# [[ 60.29066832   0.9866704 ]
#  [-33.77360185   0.30603511]
#  [-56.71482606   2.81342999]] [[-16.54457967]
#  [  5.48952936]
#  [ 14.37350176]]
# epoch: 68
# Training error 0.09922444846828728
# Testing error 0.09599189514635503
# [[ 45.75165288   1.02537369]
#  [-28.97324016   0.2484032 ]
#  [-42.60875401   2.76028092]] [[-16.7231335 ]
#  [  5.52785102]
#  [ 14.48008238]]
# epoch: 69
# Training error 0.10734901213806344
# Testing error 0.10332766462220122
# [[ 29.92695837   1.05588199]
#  [-23.7211509    0.18901462]
#  [-27.30040867   2.71418306]] [[-16.87819124]
#  [  5.58763393]
#  [ 14.56303759]]
# epoch: 70
# Training error 0.24702812752238834
# Testing error 0.2367301252433785
# [[ 19.22849084   0.36040969]
#  [-19.97364565   0.36162919]
#  [-16.90886631   3.30826141]] [[-16.80996517]
#  [  5.31641967]
#  [ 14.75748442]]
# epoch: 71
# Training error 0.2481837111535475
# Testing error 0.23790427505652165
# [[ 19.1713487    0.52465104]
#  [-19.98183401   0.22457709]
#  [-16.70070998   3.15997958]] [[-16.8112112 ]
#  [  5.41929562]
#  [ 14.75663565]]
# epoch: 72
# Training error 0.24764302225899945
# Testing error 0.2372723710477283
# [[ 19.2102052    0.40634183]
#  [-20.01996283   0.19877654]
#  [-16.61877151   3.26270743]] [[-16.84938001]
#  [  5.46789876]
#  [ 14.75499583]]
# epoch: 73
# Training error 0.2474127253952003
# Testing error 0.23699374503663123
# [[ 19.39883621   0.37912373]
#  [-20.11671302   0.14411576]
#  [-16.69104907   3.28493853]] [[-16.88863736]
#  [  5.54766665]
#  [ 14.73927554]]
# epoch: 74
# Training error 0.24713977339401744
# Testing error 0.23667476896632764
# [[ 19.59101274   0.34139401]
#  [-20.21463768   0.09864867]
#  [-16.77766813   3.3161837 ]] [[-16.92578346]
#  [  5.62718009]
#  [ 14.72348662]]
# epoch: 75
# Training error 0.24690265066979178
# Testing error 0.23639652559167115
# [[ 19.78229592   0.3083584 ]
#  [-20.31222964   0.05618081]
#  [-16.87223928   3.34313171]] [[-16.95890466]
#  [  5.70777887]
#  [ 14.70804761]]
# epoch: 76
# Training error 0.24670378742469104
# Testing error 0.23615869254686406
# [[ 1.99625794e+01  2.78325365e-01]
#  [-2.04053646e+01  1.69085508e-02]
#  [-1.69638190e+01  3.36730066e+00]] [[-16.98971586]
#  [  5.78532509]
#  [ 14.69261198]]
# epoch: 77
# Training error 0.2465341782096262
# Testing error 0.23595278520067875
# [[ 2.01307771e+01  2.49656834e-01]
#  [-2.04934525e+01 -1.90167500e-02]
#  [-1.70504474e+01  3.39017648e+00]] [[-17.01787809]
#  [  5.85958429]
#  [ 14.67790345]]
# epoch: 78
# Training error 0.24638979893548923
# Testing error 0.23577489016378325
# [[ 20.28758588   0.22260776]
#  [-20.57667196  -0.05212721]
#  [-17.13195735   3.41157432]] [[-17.04364399]
#  [  5.93041103]
#  [ 14.66397425]]
# epoch: 79
# Training error 0.24626643985167596
# Testing error 0.2356207466586738
# [[ 20.43375723   0.19711718]
#  [-20.65524716  -0.0827824 ]
#  [-17.20836509   3.43157475]] [[-17.06733312]
#  [  5.99772261]
#  [ 14.65079971]]
# epoch: 80
# Training error 0.2461602667008874
# Testing error 0.23548643546903447
# [[ 20.57018306   0.1730098 ]
#  [-20.72948195  -0.11125035]
#  [-17.27993095   3.45035107]] [[-17.08917566]
#  [  6.06161635]
#  [ 14.63837346]]
# epoch: 81
# Training error 0.24606822822351898
# Testing error 0.23536877316917731
# [[ 20.69777764   0.15016405]
#  [-20.79971067  -0.13777709]
#  [-17.34702175   3.46802452]] [[-17.10936739]
#  [  6.12226803]
#  [ 14.62667057]]
# epoch: 82
# Training error 0.24598791455710256
# Testing error 0.2352651816768983
# [[ 20.81738163   0.12848786]
#  [-20.8662538   -0.16258188]
#  [-17.4100051    3.48468652]] [[-17.12808687]
#  [  6.17987338]
#  [ 14.61564979]]
# epoch: 83
# Training error 0.2459173912108916
# Testing error 0.23517354142418892
# [[ 20.92974244   0.10789432]
#  [-20.9294053   -0.18585258]
#  [-17.46922013   3.50042086]] [[-17.1454926 ]
#  [  6.23463155]
#  [ 14.6052649 ]]
# epoch: 84
# Training error 0.2458550933903617
# Testing error 0.235092099381831
# [[ 21.03552154   0.08829947]
#  [-20.98943218  -0.20774943]
#  [-17.52497513   3.51530643]] [[-17.16172234]
#  [  6.28673853]
#  [ 14.59547014]]
# epoch: 85
# Training error 0.2457997509673977
# Testing error 0.2350194022449012
# [[ 21.13530447   0.06962516]
#  [-21.0465763   -0.22841027]
#  [-17.57754906   3.52941536]] [[-17.17689555]
#  [  6.33638231]
#  [ 14.58622176]]
# epoch: 86
# Training error 0.24575032843933142
# Testing error 0.23495424114330585
# [[ 21.22960984   0.05180022]
#  [-21.10105623  -0.24795467]
#  [-17.6271934    3.54281242]] [[-17.19111625]
#  [  6.38373977]
#  [ 14.57747851]]
# epoch: 87
# Training error 0.24570597651069256
# Testing error 0.2348956057894967
# [[ 21.31889733   0.03476025]
#  [-21.15306924  -0.26648685]
#  [-17.67413424   3.55555553]] [[-17.20447545]
#  [  6.42897523]
#  [ 14.5692019 ]]
# epoch: 88
# Training error 0.24566599393334468
# Testing error 0.2348426474371957
# [[ 2.14035752e+01  1.84468931e-02]
#  [-2.12027934e+01 -2.84097932e-01]
#  [-1.77185748e+01  3.56769665e+00]] [[-17.21705303]
#  [  6.47224016]
#  [ 14.56135636]]
# epoch: 89
# Training error 0.24562979782476482
# Testing error 0.23479464936417957
# [[ 2.14840069e+01  2.80719167e-03]
#  [-2.12503895e+01 -3.00867953e-01]
#  [-1.77606978e+01  3.57928254e+00]] [[-17.22891932]
#  [  6.51367361]
#  [ 14.55390918]]
# epoch: 90
# Training error 0.24559690059373215
# Testing error 0.23475100336272897
# [[ 2.15605172e+01 -1.22069711e-02]
#  [-2.12960033e+01 -3.16867429e-01]
#  [-1.78006682e+01  3.59035530e+00]] [[-17.24013637]
#  [  6.55340291]
#  [ 14.54683049]]
# epoch: 91
# Training error 0.2455668918959986
# Testing error 0.2347111909112341
# [[ 21.63339686  -0.02663933]
#  [-21.3397668   -0.33215875]
#  [-17.83863511   3.60095297]] [[-17.25075913]
#  [  6.5915445 ]
#  [ 14.54009302]]
# epoch: 92
# Training error 0.24553942441558463
# Testing error 0.23467476799320458
# [[ 21.70290723  -0.04052965]
#  [-21.38179997  -0.34679735]
#  [-17.87473347   3.61110988]] [[-17.26083642]
#  [  6.62820487]
#  [ 14.53367192]]
# epoch: 93
# Training error 0.24551420257895257
# Testing error 0.23464135278217105
# [[ 21.76928391  -0.05391416]
#  [-21.42221212  -0.36083263]
#  [-17.90908602   3.62085714]] [[-17.27041169]
#  [  6.66348135]
#  [ 14.52754455]]
# epoch: 94
# Training error 0.2454909735384315
# Testing error 0.23461061559839033
# [[ 21.83273982  -0.06682584]
#  [-21.46110302  -0.37430881]
#  [-17.94180449   3.63022295]] [[-17.2795238 ]
#  [  6.69746301]
#  [ 14.52169028]]
# epoch: 95
# Training error 0.24546951992531066
# Testing error 0.23458227067907525
# [[ 21.89346798  -0.07929482]
#  [-21.4985639   -0.3872656 ]
#  [-17.97299087   3.6392329 ]] [[-17.28820758]
#  [  6.7302314 ]
#  [ 14.51609031]]
# epoch: 96
# Training error 0.24544965399194524
# Testing error 0.23455606940416812
# [[ 21.95164384  -0.09134863]
#  [-21.53467841  -0.39973875]
#  [-18.0027385    3.64791029]] [[-17.29649435]
#  [  6.76186128]
#  [ 14.51072747]]
# epoch: 97
# Training error 0.24543121285026553
# Testing error 0.23453179469568752
# [[ 22.00742724  -0.10301248]
#  [-21.56952334  -0.41176057]
#  [-18.03113295   3.65627638]] [[-17.30441232]
#  [  6.79242124]
#  [ 14.50558607]]
# epoch: 98
# Training error 0.24541405458034599
# Testing error 0.23450925636735723
# [[ 22.06096422  -0.11430952]
#  [-21.60316937  -0.42336033]
#  [-18.05825283   3.66435057]] [[-17.31198701]
#  [  6.82197434]
#  [ 14.50065176]]
# epoch: 99
# Training error 0.24539805503307469
# Testing error 0.23448828724698045
# [[ 22.11238846  -0.12526098]
#  [-21.63568169  -0.43456463]
#  [-18.08417057   3.67215064]] [[-17.31924156]
#  [  6.8505786 ]
#  [ 14.4959114 ]]
# epoch: 100
# Training error 0.24538310518949247
# Testing error 0.234468739929877
# [[ 22.16182265  -0.13588642]
#  [-21.66712051  -0.4453977 ]
#  [-18.10895294   3.67969289]] [[-17.32619697]
#  [  6.87828751]
#  [ 14.49135293]]

# %%
# The follwoing is for XOR
# number of test cases

#initialisation of weight vectors
alpha=np.random.uniform(-4,4,6)
alpha=alpha.reshape(3,2)
beta=np.array([np.random.uniform(-4,4,3)]).T


# The follwoing is for AND
# number of test cases
T=5000
N=int(0.8*T)
M=int(0.2*T)

y=np.ones(T)

# each node in input layer is either 0 or 1 (with some noise)
x1=np.random.randint(0,2,T)
x2=np.random.randint(0,2,T)

#converting to float
x1=x1.astype(float)
x2=x2.astype(float)

#if both nodes are 1 then output node should be 1
for i in range(T):
    if x1[i]==0 and x2[i]==0:
        y[i]=0
    elif x1[i] and x2[i]:
        y[i]=0
        
#adding noise
x1 += np.random.normal(mean, std, T)
x2 += np.random.normal(mean, std, T)

# appending a row of ones, reshaping the matrix
X=np.array([np.ones(T),x1,x2])
X=X.reshape(3,T)


#plotting the input data points
plt.plot(X[1,:],X[2,:],'o',label='pts')
plt.legend()
plt.grid(1)
plt.xlabel('x1')
plt.ylabel('x2') 
plt.show()

#size of mini batch
m=50
#number of epochs
epoch =100
#learning rate
gamma=0.05

#The vector for mse values of training data
R_train=np.empty([1])
#The vector for mse values of testing data
R_test=np.empty([1])

# looping over epoch
for i in range(epoch):
    #looping over the mini batches
    for j in range(N//m):
        #z is sgm(alpha.T * X)
        z=np.matmul(alpha.T,X[:,j*m:(j+1)*m])
        z=z.reshape(1,2*m)
        for idx in range(2*m):
            z[0][idx]=sigmoid(z[0][idx]) 
        
        z=np.append(np.ones(m),z)
        z=z.reshape(3,m)     
        #y_cap is sigmoid of beta.T * z
        y_cap=np.matmul(beta.T,z)
        
        for idx in range(m):
            y_cap[0][idx]=sigmoid(y_cap[0][idx])
        #print(beta,y_cap)
        delta=-2*(y[j*m:(j+1)*m]-y_cap)
        
        #making the delta vector( 1 cross m)
        for idx in range(m):
                delta[0][idx]=delta[0][idx]*sigmoid_der(np.dot(beta.T,z[:,idx]))
        # making the S matrix (3 cross m)
        S=np.matmul(beta,delta)
        for idx in range(3):
            for itr in range(m):
                S[idx][itr]=S[idx][itr]*sigmoid(z[idx][itr])*(1-sigmoid(z[idx][itr]))
        
        #updating the weight vector
        beta-=gamma*np.matmul(z,delta.T)
        alpha-=gamma*np.matmul(S,X[1:,j*m:(j+1)*m].T)
        
    # finding z after every epoch        
    z=np.matmul(alpha.T,X)
    z=z.reshape(1,2*T)
    for idx in range(2*T):
        z[0][idx]=sigmoid(z[0][idx])
    
    z=np.append(np.ones(T),z)
    z=z.reshape(3,T)
    
    #finding the y cap after every epoch 
    y_cap=np.matmul(beta.T,z)   
    for idx in range(T):
        y_cap[0][idx]=sigmoid(y_cap[0][idx])
    
    # storing the errors in an array
    print("epoch:",i+1)
    R_train=np.append(R_train,np.sum((y[:N]-y_cap[0,:N])**2)/N)
    R_test=np.append(R_test,np.sum((y[N:T]-y_cap[0,N:T])**2)/M)
    print("Training error",np.sum((y[:N]-y_cap[0,:N])**2)/N)
    print("Testing error",np.sum((y[N:T]-y_cap[0,N:T])**2)/M)
    
#plotting the results
plt.plot(np.linspace(1,epoch,epoch),R_train[1:], 'r',label='training error')
plt.plot(np.linspace(1,epoch,epoch),R_test[1:],label='testing error')
plt.legend()
plt.grid()
plt.show()
# Out:
# epoch: 1
# Training error 0.21197174026641039
# Testing error 0.212688181838604
# epoch: 2
# Training error 0.18933665872806416
# Testing error 0.1914691315782464
# epoch: 3
# Training error 0.18468086478492557
# Testing error 0.18621857491496477
# epoch: 4
# Training error 0.1984827067144868
# Testing error 0.20054412273166375
# epoch: 5
# Training error 0.21717160025201157
# Testing error 0.21997431852848431
# epoch: 6
# Training error 0.23256659315268388
# Testing error 0.23588995617169184
# epoch: 7
# Training error 0.2437584005902147
# Testing error 0.2473352861792847
# epoch: 8
# Training error 0.25189170355034673
# Testing error 0.25551149296128917
# epoch: 9
# Training error 0.25719680288170116
# Testing error 0.26060654149430845
# epoch: 10
# Training error 0.26044163427876904
# Testing error 0.2634414181608902
# epoch: 11
# Training error 0.26236813375603923
# Testing error 0.26487105882048395
# epoch: 12
# Training error 0.26229386033452623
# Testing error 0.2642367991028403
# epoch: 13
# Training error 0.2588848630885707
# Testing error 0.2602139003266099
# epoch: 14
# Training error 0.25321992272238525
# Testing error 0.2539991114769941
# epoch: 15
# Training error 0.24934399782637864
# Testing error 0.24977730134487677
# epoch: 16
# Training error 0.2483265657570517
# Testing error 0.24859535679780004
# epoch: 17
# Training error 0.2486699332670474
# Testing error 0.24887763945412872
# epoch: 18
# Training error 0.2492933949961855
# Testing error 0.2494955304922457
# epoch: 19
# Training error 0.24979620612326436
# Testing error 0.25002358224435817
# epoch: 20
# Training error 0.2500947161248914
# Testing error 0.2503642396322521
# epoch: 21
# Training error 0.2502182210564876
# Testing error 0.25053809620964707
# epoch: 22
# Training error 0.25022498919357267
# Testing error 0.2505976385722317
# epoch: 23
# Training error 0.25016997241082173
# Testing error 0.25059394058996487
# epoch: 24
# Training error 0.25009411081535865
# Testing error 0.25056542695135353
# epoch: 25
# Training error 0.2500230256845649
# Testing error 0.25053621765003714
# epoch: 26
# Training error 0.24996959362042986
# Testing error 0.2505184455229815
# epoch: 27
# Training error 0.24993766541986007
# Testing error 0.2505157735831025
# epoch: 28
# Training error 0.24992559065318687
# Testing error 0.2505267581575783
# epoch: 29
# Training error 0.24992899872013646
# Testing error 0.25054750075513843
# epoch: 30
# Training error 0.24994272314825294
# Testing error 0.25057347001166663
# epoch: 31
# Training error 0.24996196728132986
# Testing error 0.25060058756787734
# epoch: 32
# Training error 0.24998288663430906
# Testing error 0.25062574965064555
# epoch: 33
# Training error 0.2500027692454009
# Testing error 0.25064696280504
# epoch: 34
# Training error 0.2500199696340999
# Testing error 0.25066324693553177
# epoch: 35
# Training error 0.2500337159595889
# Testing error 0.25067442304828774
# epoch: 36
# Training error 0.2500438741240984
# Testing error 0.2506808673545427
# epoch: 37
# Training error 0.25005072147586693
# Testing error 0.2506832823762121
# epoch: 38
# Training error 0.2500547581861541
# Testing error 0.2506825112119892
# epoch: 39
# Training error 0.25005656662088044
# Testing error 0.2506794035328563
# epoch: 40
# Training error 0.25005671756759557
# Testing error 0.2506747306529233
# epoch: 41
# Training error 0.25005571593819265
# Testing error 0.25066914106860616
# epoch: 42
# Training error 0.2500539762007544
# Testing error 0.25066314579625726
# epoch: 43
# Training error 0.2500518179439895
# Testing error 0.25065712327665624
# epoch: 44
# Training error 0.2500494734831921
# Testing error 0.2506513353689782
# epoch: 45
# Training error 0.25004710141825387
# Testing error 0.25064594815572755
# epoch: 46
# Training error 0.2500448020086283
# Testing error 0.25064105337853687
# epoch: 47
# Training error 0.2500426318591924
# Testing error 0.2506366880497877
